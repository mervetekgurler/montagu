# %% [markdown]
# <center><b>Python Programming for Multilingual Text</b></center>
# <center>2-4: Introduction to Text Analysis with Montagu Corpus</center>
#
# ---

# %% [markdown]
# # Introduction to Text Analysis with Montagu Corpus

# %% [markdown]
# ## Overview
#
# This notebook introduces some basic string methods using examples from Lady Mary Montagu's letters. It applied and thus reinforces what we have learnt in the previous notebooks about Python more generally.
#
# 1. Data Import: We will read in `Letter 35` and prepare it for analysis
# 2. String Operation: We will look at some string operations
# 3. Counting Words: Tokenization, Text normalization, most frequent words
# 4. Stopwords: stopword removal, NLTK
# 5. Sentences: NLTK, initial discussions of syntax

# %% [markdown]
# ## Step 1: Letter 35

# %%
letter_35 = open("../../output/montagu_letters/letter_35.txt").read()
print(letter_35)
# Out:
# LET. XXXV.
#
# To THE ABBOT ----.
#
# _Constantinople, May_ 29. O. S.
#
# I HAVE had the advantage of very fine weather, all my journey; and as
# the summer is now in its beauty, I enjoyed the pleasure of fine
# prospects; and the meadows being full of all sorts of garden flowers,
# and sweet herbs, my berlin perfumed the air as it pressed them.  The
# grand signior furnished us with thirty covered waggons for our
# baggage, and five coaches of the country for my women.  We found the
# road full of the great spahis and their equipages coming out of Asia
# to the war.  They always travel with tents; but I chose to ly in
# houses all the way.  I will not trouble you with the names of the
# villages we passed, in which there was nothing remarkable, but at
# Ciorlei, where there was a _conac_, or little seraglio, built for the
# use of the grand signior, when he goes this road.  I had the
# curiosity to view all the apartments destined for the ladies of his
# court.  They were in the midst of a thick grove of trees, made fresh
# by fountains; but I was most surprised to see the walls almost
# covered with little distiches of Turkish verse, wrote with pencils.
# I made my interpreter explain them to me, and I found several of them
# very well turned; though I easily believed him, that they had lost
# much of their beauty in the translation.  One was literally thus in
# English:
#
#          _We come into this world; we lodge, and we depart;
#           He never goes, that's lodged within my heart._
#
# THE rest of our journey was through fine painted meadows, by the side
# of the sea of Marmora, the ancient Propontis.  We lay the next night
# at Selivrea, anciently a noble town.  It is now a good sea-port, and
# neatly built enough, and has a bridge of thirty-two arches.  Here is
# a famous ancient Greek church.  I had given one of my coaches to a
# Greek lady, who desired the conveniency of travelling with me; she
# designed to pay her devotions, and I was glad of the opportunity of
# going with her.  I found it an ill-built edifice, set out with the
# same sort of ornaments, but less rich, as the Roman-catholic
# churches.  They shewed me a saint's body, where I threw a piece of
# money; and a picture of the virgin Mary, drawn by the hand of St
# Luke, very little to the credit of his painting; but, however, the
# finest Madona (sic) of Italy, is not more famous for her miracles.
# The Greeks have a monstrous taste in their pictures, which, for more
# finery, are always drawn upon a gold ground.  You may imagine what a
# good air this has; but they have no notion, either of shade or
# proportion.  They have a bishop here, who officiated in his purple
# robe, and sent me a candle almost as big as myself for a present,
# when I was at my lodging.  We lay that night at a town called Bujuk
# Cekmege, or Great Bridge; and the night following, at Kujuk Cekmege,
# or Little Bridge; in a very pleasant lodging, formerly a monastery of
# dervises; having before it a large court, encompassed with marble
# cloisters, with a good fountain in the middle.  The prospect from
# this place, and the gardens round it, is the most agreeable I have
# seen; and shews, that monks of all religions know how to chuse their
# retirements.  'Tis now belonging to a _hogia_ or schoolmaster, who
# teaches boys here.  I asked him to shew me his own apartment, and was
# surprised to see him point to a tall cypress tree in the garden, on
# the top of which was a place for a bed for himself, and a little
# lower, one for his wife and two children, who slept there every
# night.  I was so much diverted with the fancy, I resolved to examine
# his nest nearer; but after going up fifty steps, I found I had still
# fifty to go up, and then I must climb from branch to branch, with
# some hazard of my neck.  I thought it therefore the best way to come
# down again.
#
# WE arrived the next day at Constantinople; but I can yet tell you
# very little of it, all my time having been taken up with receiving
# visits, which are, at least, a very good entertainment to the eyes,
# the young women being all beauties, and their beauty highly improved
# by the high taste of their dress.  Our palace is in Pera, which is no
# more a suburb of Constantinople, than Westminster is a suburb to
# London.  All the ambassadors are lodged very near each other.  One
# part of our house shews us the port, the city, and the seraglio, and
# the distant hills of Asia; perhaps, all together, the most beautiful
# prospect in the world.
#
# A CERTAIN French author says, Constantinople is twice as big as
# Paris.  Mr W----y is unwilling to own 'tis bigger than London, though
# I confess it appears to me to be so; but I don't believe it is so
# populous.  The burying fields about it are certainly much larger than
# the whole city.  'Tis surprising what a vast deal of land is lost
# this way in Turkey.  Sometimes I have seen burying places of several
# miles, belonging to very inconsiderable villages, which were formerly
# great towns, and retain no other mark of their ancient grandeur, than
# this dismal one.  On no occasion do they ever remove a stone that
# serves for a monument.  Some of them are costly enough, being of very
# fine marble.  They set up a pillar, with a carved turbant on the top
# of it, to the memory of a man; and as the turbants, by their
# different shapes, shew the quality or profession, 'tis in a manner
# putting up the arms of the deceased; besides, the pillar commonly
# bears an inscription in gold letters.  The ladies have a simple
# pillar without other ornament, except those that die unmarried, who
# have a rose on the top of their monument.  The sepulchres of
# particular families are railed in, and planted round with trees.
# Those of the sultans, and some great men, have lamps constantly
# burning in them.
#
# WHEN I spoke of their religion, I forgot to mention two
# particularities, one of which I have read of, but it seemed so odd to
# me, I could not believe it; yet 'tis certainly true; that when a man
# has divorced his wife, in the most solemn manner, he can take her
# again, upon no other terms, than permitting another man to pass a
# night with her; and there are some examples of those who have
# submitted to this law, rather than not have back their beloved.  The
# other point of doctrine is very extraordinary.  Any woman that dies
# unmarried is looked upon to die in a state of reprobation.  To
# confirm this belief, they reason, that the end of the creation of
# woman is to increase and multiply; and that she is only properly
# employed in the works of her calling, when she is bringing forth
# children, or taking care of them, which are all the virtues that God
# expects from her.  And indeed, their way of life, which shuts them
# out of all public commerce, does not permit them any other.  Our
# vulgar notion, that they don't own women to have any souls, is a
# mistake.  'Tis true, they say, they are not of so elevated a kind,
# and therefore must not hope to be admitted into the paradise
# appointed for the men, who are to be entertained by celestial
# beauties.  But there is a place of happiness destined for souls of
# the inferior order, where all good women are to be in eternal bliss.
# Many of them are very superstitious, and will not remain widows ten
# days, for fear of dying in the reprobate state of an useless
# creature.  But those that like their liberty, and are not slaves to
# their religion, content themselves with marrying when they are afraid
# of dying.  This is a piece of theology, very different from that
# which teaches nothing to be more acceptable to God than a vow of
# perpetual virginity: which divinity is most rational, I leave you to
# determine.
#
# I HAVE already made some progress in a collection of Greek medals.
# Here are several professed antiquaries, who are ready to serve any
# body that desires them.  But you cannot imagine how they stare in my
# face, when I enquire about them, as if no body was permitted to seek
# after medals, till they were grown a piece of antiquity themselves.
# I have got some very valuable ones of the Macedonian kings,
# particularly one of Perseus, so lively, I fancy I can see all his ill
# qualities in his face.  I have a prophyry (sic) head finely cut, of
# the true Greek sculpture; but who it represents, is to be guessed at
# by the learned when I return.  For you are not to suppose these
# antiquaries (who are all Greeks) know any thing.  Their trade is only
# to sell; they have correspondents at Aleppo, Grand Cairo, in Arabia
# and Palestine, who send them all they can find, and very often great
# heaps, that are only fit to melt into pans and kettles.  They get the
# best price they can for them, without knowing those that are valuable
# from those that are not.  Those that pretend to skill, generally find
# out the image of some saint in the medals of the Greek cities.  One
# of them, shewing me the figure of a Pallas, with a victory in her
# hand on a reverse, assured me, it was the Virgin, holding a crucifix.
# The same man offered me the head of a Socrates, on a sardonyx; and,
# to enhance the value, gave him the title of saint Augustine.  I have
# bespoke a mummy, which I hope will come safe to my hands,
# notwithstanding the misfortune that befel (sic) a very fine one,
# designed for the king of Sweden.  He gave a great price for it, and
# the Turks took it into their heads, that he must have some
# considerable project depending upon it.  They fancied it the body of,
# God knows who; and that the state of their empire mystically depended
# on the conversation of it.  Some old prophecies were remembered upon
# this occasion, and the mummy committed prisoner to the Seven Towers,
# where it has remained under close confinement ever since, I dare not
# try my interest in so considerable a point, as the release of it; but
# I hope mine will pass without examination.  I can  tell you nothing
# more at present of this famous city.  When I have looked a little
# about me, you shall hear from me again.  I am, Sir,   Your's, &c. &c.

# %% [markdown]
# For this notebook, we want to only work with the body of the letter and not the metadata.
#
# <div style="background: rgba(167, 139, 250, 0.12); border-radius: 6px; padding: 0.6em 1em; margin: 1.5em 0; font-weight: 500;">
#   Let's remove the metadata on the fly.
# </div>

# %% [markdown]
# ### 🥊 Challenge 1: Remove the metadata
#
# Hint: there are probably more ways to tackle this than we could think of. This is the beauty of coding, we will each have a unique approach to solving this

# %%
## YOUR CODE HERE

# %% [markdown]
# This is how I would do it (in pseudocode)
#
# - find the start of the letter
#     - it begins with "I HAVE"
#     - search for "I HAVE" in the letter
#     - verify that there is only one instance of it
#     - get the index using .find() method
# - use the start index to split the metadata from the body
#     - we can slice a string using indices
#     - remember that the end index in a slice is *exclusive*
#     - verify that the split is correct
# - delete everything until the letter body
#     - this will modify the variable 'letter_35'

# %%
# I know where the body of the letter begins

letter_start = letter_35.find("I HAVE")
print(letter_start)
# Out:
# 65

# %%
# let's get the metadata to verify our approach
letter_metadata = letter_35[:letter_start]
print(letter_metadata)
# Out:
# LET. XXXV.
#
# To THE ABBOT ----.
#
# _Constantinople, May_ 29. O. S.

# %%
# Looking good! We can now use the same logic to modify our letter_35
# this is an irreversable change because we are assigning it back to the variable itself!

letter_35 = letter_35[letter_start:]
print(letter_35)
# Out:
# I HAVE had the advantage of very fine weather, all my journey; and as
# the summer is now in its beauty, I enjoyed the pleasure of fine
# prospects; and the meadows being full of all sorts of garden flowers,
# and sweet herbs, my berlin perfumed the air as it pressed them.  The
# grand signior furnished us with thirty covered waggons for our
# baggage, and five coaches of the country for my women.  We found the
# road full of the great spahis and their equipages coming out of Asia
# to the war.  They always travel with tents; but I chose to ly in
# houses all the way.  I will not trouble you with the names of the
# villages we passed, in which there was nothing remarkable, but at
# Ciorlei, where there was a _conac_, or little seraglio, built for the
# use of the grand signior, when he goes this road.  I had the
# curiosity to view all the apartments destined for the ladies of his
# court.  They were in the midst of a thick grove of trees, made fresh
# by fountains; but I was most surprised to see the walls almost
# covered with little distiches of Turkish verse, wrote with pencils.
# I made my interpreter explain them to me, and I found several of them
# very well turned; though I easily believed him, that they had lost
# much of their beauty in the translation.  One was literally thus in
# English:
#
#          _We come into this world; we lodge, and we depart;
#           He never goes, that's lodged within my heart._
#
# THE rest of our journey was through fine painted meadows, by the side
# of the sea of Marmora, the ancient Propontis.  We lay the next night
# at Selivrea, anciently a noble town.  It is now a good sea-port, and
# neatly built enough, and has a bridge of thirty-two arches.  Here is
# a famous ancient Greek church.  I had given one of my coaches to a
# Greek lady, who desired the conveniency of travelling with me; she
# designed to pay her devotions, and I was glad of the opportunity of
# going with her.  I found it an ill-built edifice, set out with the
# same sort of ornaments, but less rich, as the Roman-catholic
# churches.  They shewed me a saint's body, where I threw a piece of
# money; and a picture of the virgin Mary, drawn by the hand of St
# Luke, very little to the credit of his painting; but, however, the
# finest Madona (sic) of Italy, is not more famous for her miracles.
# The Greeks have a monstrous taste in their pictures, which, for more
# finery, are always drawn upon a gold ground.  You may imagine what a
# good air this has; but they have no notion, either of shade or
# proportion.  They have a bishop here, who officiated in his purple
# robe, and sent me a candle almost as big as myself for a present,
# when I was at my lodging.  We lay that night at a town called Bujuk
# Cekmege, or Great Bridge; and the night following, at Kujuk Cekmege,
# or Little Bridge; in a very pleasant lodging, formerly a monastery of
# dervises; having before it a large court, encompassed with marble
# cloisters, with a good fountain in the middle.  The prospect from
# this place, and the gardens round it, is the most agreeable I have
# seen; and shews, that monks of all religions know how to chuse their
# retirements.  'Tis now belonging to a _hogia_ or schoolmaster, who
# teaches boys here.  I asked him to shew me his own apartment, and was
# surprised to see him point to a tall cypress tree in the garden, on
# the top of which was a place for a bed for himself, and a little
# lower, one for his wife and two children, who slept there every
# night.  I was so much diverted with the fancy, I resolved to examine
# his nest nearer; but after going up fifty steps, I found I had still
# fifty to go up, and then I must climb from branch to branch, with
# some hazard of my neck.  I thought it therefore the best way to come
# down again.
#
# WE arrived the next day at Constantinople; but I can yet tell you
# very little of it, all my time having been taken up with receiving
# visits, which are, at least, a very good entertainment to the eyes,
# the young women being all beauties, and their beauty highly improved
# by the high taste of their dress.  Our palace is in Pera, which is no
# more a suburb of Constantinople, than Westminster is a suburb to
# London.  All the ambassadors are lodged very near each other.  One
# part of our house shews us the port, the city, and the seraglio, and
# the distant hills of Asia; perhaps, all together, the most beautiful
# prospect in the world.
#
# A CERTAIN French author says, Constantinople is twice as big as
# Paris.  Mr W----y is unwilling to own 'tis bigger than London, though
# I confess it appears to me to be so; but I don't believe it is so
# populous.  The burying fields about it are certainly much larger than
# the whole city.  'Tis surprising what a vast deal of land is lost
# this way in Turkey.  Sometimes I have seen burying places of several
# miles, belonging to very inconsiderable villages, which were formerly
# great towns, and retain no other mark of their ancient grandeur, than
# this dismal one.  On no occasion do they ever remove a stone that
# serves for a monument.  Some of them are costly enough, being of very
# fine marble.  They set up a pillar, with a carved turbant on the top
# of it, to the memory of a man; and as the turbants, by their
# different shapes, shew the quality or profession, 'tis in a manner
# putting up the arms of the deceased; besides, the pillar commonly
# bears an inscription in gold letters.  The ladies have a simple
# pillar without other ornament, except those that die unmarried, who
# have a rose on the top of their monument.  The sepulchres of
# particular families are railed in, and planted round with trees.
# Those of the sultans, and some great men, have lamps constantly
# burning in them.
#
# WHEN I spoke of their religion, I forgot to mention two
# particularities, one of which I have read of, but it seemed so odd to
# me, I could not believe it; yet 'tis certainly true; that when a man
# has divorced his wife, in the most solemn manner, he can take her
# again, upon no other terms, than permitting another man to pass a
# night with her; and there are some examples of those who have
# submitted to this law, rather than not have back their beloved.  The
# other point of doctrine is very extraordinary.  Any woman that dies
# unmarried is looked upon to die in a state of reprobation.  To
# confirm this belief, they reason, that the end of the creation of
# woman is to increase and multiply; and that she is only properly
# employed in the works of her calling, when she is bringing forth
# children, or taking care of them, which are all the virtues that God
# expects from her.  And indeed, their way of life, which shuts them
# out of all public commerce, does not permit them any other.  Our
# vulgar notion, that they don't own women to have any souls, is a
# mistake.  'Tis true, they say, they are not of so elevated a kind,
# and therefore must not hope to be admitted into the paradise
# appointed for the men, who are to be entertained by celestial
# beauties.  But there is a place of happiness destined for souls of
# the inferior order, where all good women are to be in eternal bliss.
# Many of them are very superstitious, and will not remain widows ten
# days, for fear of dying in the reprobate state of an useless
# creature.  But those that like their liberty, and are not slaves to
# their religion, content themselves with marrying when they are afraid
# of dying.  This is a piece of theology, very different from that
# which teaches nothing to be more acceptable to God than a vow of
# perpetual virginity: which divinity is most rational, I leave you to
# determine.
#
# I HAVE already made some progress in a collection of Greek medals.
# Here are several professed antiquaries, who are ready to serve any
# body that desires them.  But you cannot imagine how they stare in my
# face, when I enquire about them, as if no body was permitted to seek
# after medals, till they were grown a piece of antiquity themselves.
# I have got some very valuable ones of the Macedonian kings,
# particularly one of Perseus, so lively, I fancy I can see all his ill
# qualities in his face.  I have a prophyry (sic) head finely cut, of
# the true Greek sculpture; but who it represents, is to be guessed at
# by the learned when I return.  For you are not to suppose these
# antiquaries (who are all Greeks) know any thing.  Their trade is only
# to sell; they have correspondents at Aleppo, Grand Cairo, in Arabia
# and Palestine, who send them all they can find, and very often great
# heaps, that are only fit to melt into pans and kettles.  They get the
# best price they can for them, without knowing those that are valuable
# from those that are not.  Those that pretend to skill, generally find
# out the image of some saint in the medals of the Greek cities.  One
# of them, shewing me the figure of a Pallas, with a victory in her
# hand on a reverse, assured me, it was the Virgin, holding a crucifix.
# The same man offered me the head of a Socrates, on a sardonyx; and,
# to enhance the value, gave him the title of saint Augustine.  I have
# bespoke a mummy, which I hope will come safe to my hands,
# notwithstanding the misfortune that befel (sic) a very fine one,
# designed for the king of Sweden.  He gave a great price for it, and
# the Turks took it into their heads, that he must have some
# considerable project depending upon it.  They fancied it the body of,
# God knows who; and that the state of their empire mystically depended
# on the conversation of it.  Some old prophecies were remembered upon
# this occasion, and the mummy committed prisoner to the Seven Towers,
# where it has remained under close confinement ever since, I dare not
# try my interest in so considerable a point, as the release of it; but
# I hope mine will pass without examination.  I can  tell you nothing
# more at present of this famous city.  When I have looked a little
# about me, you shall hear from me again.  I am, Sir,   Your's, &c. &c.

# %% [markdown]
# ## Step 2: Simple String Operations

# %% [markdown]
# First, let's gather some basic yet important statistics about our letter

# %%
print(f"Length of letter 35: {len(letter_35)} characters")
print(f"Number of words in letter 35: {len(letter_35.split())} words")
# Out:
# Length of letter 35: 9777 characters
# Number of words in letter 35: 1799 words

# %% [markdown]
# This seems like a long letter, almost 1800 words!

# %% [markdown]
# <div style="background: rgba(167, 139, 250, 0.12); border-radius: 6px; padding: 0.6em 1em; margin: 1.5em 0; font-weight: 500;">
#   Let's see what else is in the letter other than words. Perhaps punctuation? How many punctuation marks are in this letter?
# </div>

# %%
import string

# %% [markdown]
# [String](https://www.w3schools.com/python/ref_module_string.asp) is a Python module, that is built into the language itself. It provides constants and classes for common string operations.
#
# We use it to access predefined sets of characters (letters, digits, punctuation)

# %%
print(type(string.punctuation))
print(string.punctuation)
# Out:
# <class 'str'>
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %% [markdown]
# ### 🥊 Challenge 2: Count Punctuation
#
# Hint: remember what we learnt about for-loops in notebook `2-2_iteration`

# %%
# Take a second and try to implement a solution

## YOUR CODE HERE

# %% [markdown]
# Here is how I would do it
#
# - string.punctuation gives us all ASCII punctuation characters
# - start a count at 0
# - loop over each character in my letter and see if it is punctuation, meaning included in string.punctuation
# - if it is increase the count by 1

# %%
# initiate count
punctuation_count = 0

# loop over letter_35
for char in letter_35:
    if char in string.punctuation:
        punctuation_count += 1

print(punctuation_count)
# Out:
# 295

# %% [markdown]
# Another way to approach this is to loop over each character in string.punctuation and for each character call the count function on letter_35 to get how many of a given character appears in letter_35. count() returns an integer, which we can then add to our count

# %%
# initiate count
punct_count = 0

# loop over string.punctuation
for char in string.punctuation:
    # count how many of a given punctuation character appears in letter_35
    punct_count += letter_35.count(char)

print(punct_count)
# Out:
# 295

# %% [markdown]
# The result is the same in both approaches! Which do you prefer?

# %% [markdown]
# Let's see what percentage of our letter was punctuation

# %%
print("Percentage of punctuation marks in letter 35:")
print(f"{(punctuation_count / len(letter_35)) * 100:.2f}%")
# Out:
# Percentage of punctuation marks in letter 35:
# 3.02%

# %% [markdown]
# ### 🥊 Challenge 3: Unique Punctuation Marks
#
# Hint: Remember notebook `1-6_data_structures`?

# %% [markdown]
# <div style="background: rgba(167, 139, 250, 0.12); border-radius: 6px; padding: 0.6em 1em; margin: 1.5em 0; font-weight: 500;">
#   Which punctuation marks appear in this letter?
# </div>

# %%
### YOUR CODE HERE

# %% [markdown]
# Here is how I would do it:
#
# - create a list
# - loop over string.punctuation
# - check if punctuation mark is in letter_35
# - if yes, add punctuation mark to the list

# %%
# empty list

punctuation_marks = []

for punct in string.punctuation:
    if punct in letter_35:
        punctuation_marks.append(punct)
print(punctuation_marks)
# Out:
# ['&', "'", '(', ')', ',', '-', '.', ':', ';', '_']

# %% [markdown]
# ### 🥊 Challenge 4: How Many of Each Punctuation
#
# Hint: Remember dictionaries from notebook `1-6_data_structures`?

# %% [markdown]
# <div style="background: rgba(167, 139, 250, 0.12); border-radius: 6px; padding: 0.6em 1em; margin: 1.5em 0; font-weight: 500;">
#   Count how many times each punctuation mark appears in the text
# </div>

# %%
### YOUR CODE HERE

# %% [markdown]
# Here is how I would do it:
#
# - initiate an empty dictionary
# - loop over each punctuation mark in string.punctuation
# - use count() to see how many times they appear in letter_35
# - using the punctuation mark as the key and the count as the value, add it to the dictionary

# %%
# initiate dictionary
punct_amount = {}

# loop over punctuation
for char in string.punctuation:
    # get a count
    count = letter_35.count(char)
    # if count exists
    if count:
        # add the punctuation and its count to the dictionary
        punct_amount[char] = count

print(punct_amount)
# Out:
# {'&': 2, "'": 11, '(': 4, ')': 4, ',': 158, '-': 8, '.': 70, ':': 2, ';': 30, '_': 6}

# %% [markdown]
# Alternatively, we have an amazing Python module to help with this problem: [collections](https://docs.python.org/3/library/collections.html) and especially `Counter`

# %%
from collections import Counter

# %% [markdown]
# Here is the trick, Counter() works the best for tallying over a list of strings, which as we will see later, is an amazing feature.
#
# It also means that we need to first filter our letter_35, keeping only the punctuation marks that appear in the letter.

# %%
# we are using list comprehension here, which is the other iteration method we studied in notebook 2-2_iterations

punct_only_letter = [char for char in letter_35 if char in string.punctuation]

print(punct_only_letter)
# Out:
# [',', ';', ',', ';', ',', ',', '.', ',', '.', '.', ';', '.', ',', ',', ',', '_', '_', ',', ',', ',', '.', '.', ',', ';', ',', '.', ',', ';', ',', '.', ':', '_', ';', ',', ';', ',', "'", '.', '_', ',', ',', '.', ',', '.', '-', ',', ',', '-', '.', '.', ',', ';', ',', '.', '-', ',', ',', ',', '-', '.', "'", ',', ';', ',', ',', ';', ',', ',', '(', ')', ',', '.', ',', ',', ',', '.', ';', ',', '.', ',', ',', ',', '.', ',', ';', ',', ',', ';', ',', ';', ',', ',', '.', ',', ',', ';', ',', '.', "'", '_', '_', ',', '.', ',', ',', ',', ',', ',', '.', ',', ';', ',', ',', ',', '.', '.', ';', ',', ',', ',', ',', ',', ',', '.', ',', ',', '.', '.', ',', ',', ',', ';', ',', ',', '.', ',', '.', '-', '-', '-', '-', "'", ',', ';', "'", '.', '.', "'", '.', ',', ',', ',', ',', '.', '.', ',', '.', ',', ',', ';', ',', ',', ',', "'", ';', ',', '.', ',', ',', '.', ',', '.', ',', ',', '.', ',', ',', ',', ',', ';', "'", ';', ',', ',', ',', ',', ';', ',', '.', '.', '.', ',', ',', ';', ',', ',', ',', '.', ',', ',', ',', '.', ',', "'", ',', '.', "'", ',', ',', ',', ',', '.', ',', '.', ',', ',', '.', ',', ',', '.', ',', ':', ',', '.', '.', ',', '.', ',', ',', ',', '.', ',', ',', ',', '.', '(', ')', ',', ';', ',', '.', '(', ')', '.', ';', ',', ',', ',', ',', ',', '.', ',', '.', ',', '.', ',', ',', ',', ',', ',', '.', ',', ';', ',', ',', '.', ',', ',', '(', ')', ',', '.', ',', ',', '.', ',', ';', '.', ',', ',', ',', ',', ';', '.', '.', ',', '.', ',', ',', "'", ',', '&', '.', '&', '.']

# %%
punct_cnt = Counter(punct_only_letter)

print(punct_cnt)
# Out:
# Counter({',': 158, '.': 70, ';': 30, "'": 11, '-': 8, '_': 6, '(': 4, ')': 4, ':': 2, '&': 2})

# %% [markdown]
# This might seem like an overly complicated way to just count punctuation marks but Counter will be super useful in the next step

# %% [markdown]
# <mark style="background: rgba(167, 139, 250, 0.3); color: inherit; border-radius: 3px; padding: 0 2px;">There are so many other things we can count, whitespace, numbers, capitalized letters, etc. We strongly urge you to implement your own approaches for dissecting and counting different aspects of the letter</mark>

# %% [markdown]
# ## Step 3: Counting Words

# %% [markdown]
# <div style="background: rgba(167, 139, 250, 0.12); border-radius: 6px; padding: 0.6em 1em; margin: 1.5em 0; font-weight: 500;">
#   To count words, we need to find words.
# </div>

# %% [markdown]
# Now that we warmed up by counting punctuation, let's tackle the elephant in the room: **tokens**
#
# You probably heard of tokens in the context of large language models, and we will get to that in the next few days, but for the purposes of this notebook, let's stick to an older definition of a token:
#
# > Tokenization is the process of splitting text into _something_ - often words. **Each word is called a "token"** and a word such as "the" might adhere to multiple tokens of "the" within a text based on its capitalization, punctuation, etc.
#
# The `.split()` method allows us to split the text based on some sort of separator. The default is blank and will split on the white spaces between words. As such, we are using the `.split()` method as our **tokenizer**.

# %%
# Let's split our letter into words

letter_35.split()
# Out:
# ['I',
#  'HAVE',
#  'had',
#  'the',
#  'advantage',
#  'of',
#  'very',
#  'fine',
#  'weather,',
#  'all',
#  'my',
#  'journey;',
#  'and',
#  'as',
#  'the',
#  'summer',
#  'is',
#  'now',
#  'in',
#  'its',
#  'beauty,',
#  'I',
#  'enjoyed',
#  'the',
#  'pleasure',
#  'of',
#  'fine',
#  'prospects;',
#  'and',
#  'the',
#  'meadows',
#  'being',
#  'full',
#  'of',
#  'all',
#  'sorts',
#  'of',
#  'garden',
#  'flowers,',
#  'and',
#  'sweet',
#  'herbs,',
#  'my',
#  'berlin',
#  'perfumed',
#  'the',
#  'air',
#  'as',
#  'it',
#  'pressed',
#  'them.',
#  'The',
#  'grand',
#  'signior',
#  'furnished',
#  'us',
#  'with',
#  'thirty',
#  'covered',
#  'waggons',
#  'for',
#  'our',
#  'baggage,',
#  'and',
#  'five',
#  'coaches',
#  'of',
#  'the',
#  'country',
#  'for',
#  'my',
#  'women.',
#  'We',
#  'found',
#  'the',
#  'road',
#  'full',
#  'of',
#  'the',
#  'great',
#  'spahis',
#  'and',
#  'their',
#  'equipages',
#  'coming',
#  'out',
#  'of',
#  'Asia',
#  'to',
#  'the',
#  'war.',
#  'They',
#  'always',
#  'travel',
#  'with',
#  'tents;',
#  'but',
#  'I',
#  'chose',
#  'to',
#  'ly',
#  'in',
#  'houses',
#  'all',
#  'the',
#  'way.',
#  'I',
#  'will',
#  'not',
#  'trouble',
#  'you',
#  'with',
#  'the',
#  'names',
#  'of',
#  'the',
#  'villages',
#  'we',
#  'passed,',
#  'in',
#  'which',
#  'there',
#  'was',
#  'nothing',
#  'remarkable,',
#  'but',
#  'at',
#  'Ciorlei,',
#  'where',
#  'there',
#  'was',
#  'a',
#  '_conac_,',
#  'or',
#  'little',
#  'seraglio,',
#  'built',
#  'for',
#  'the',
#  'use',
#  'of',
#  'the',
#  'grand',
#  'signior,',
#  'when',
#  'he',
#  'goes',
#  'this',
#  'road.',
#  'I',
#  'had',
#  'the',
#  'curiosity',
#  'to',
#  'view',
#  'all',
#  'the',
#  'apartments',
#  'destined',
#  'for',
#  'the',
#  'ladies',
#  'of',
#  'his',
#  'court.',
#  'They',
#  'were',
#  'in',
#  'the',
#  'midst',
#  'of',
#  'a',
#  'thick',
#  'grove',
#  'of',
#  'trees,',
#  'made',
#  'fresh',
#  'by',
#  'fountains;',
#  'but',
#  'I',
#  'was',
#  'most',
#  'surprised',
#  'to',
#  'see',
#  'the',
#  'walls',
#  'almost',
#  'covered',
#  'with',
#  'little',
#  'distiches',
#  'of',
#  'Turkish',
#  'verse,',
#  'wrote',
#  'with',
#  'pencils.',
#  'I',
#  'made',
#  'my',
#  'interpreter',
#  'explain',
#  'them',
#  'to',
#  'me,',
#  'and',
#  'I',
#  'found',
#  'several',
#  'of',
#  'them',
#  'very',
#  'well',
#  'turned;',
#  'though',
#  'I',
#  'easily',
#  'believed',
#  'him,',
#  'that',
#  'they',
#  'had',
#  'lost',
#  'much',
#  'of',
#  'their',
#  'beauty',
#  'in',
#  'the',
#  'translation.',
#  'One',
#  'was',
#  'literally',
#  'thus',
#  'in',
#  'English:',
#  '_We',
#  'come',
#  'into',
#  'this',
#  'world;',
#  'we',
#  'lodge,',
#  'and',
#  'we',
#  'depart;',
#  'He',
#  'never',
#  'goes,',
#  "that's",
#  'lodged',
#  'within',
#  'my',
#  'heart._',
#  'THE',
#  'rest',
#  'of',
#  'our',
#  'journey',
#  'was',
#  'through',
#  'fine',
#  'painted',
#  'meadows,',
#  'by',
#  'the',
#  'side',
#  'of',
#  'the',
#  'sea',
#  'of',
#  'Marmora,',
#  'the',
#  'ancient',
#  'Propontis.',
#  'We',
#  'lay',
#  'the',
#  'next',
#  'night',
#  'at',
#  'Selivrea,',
#  'anciently',
#  'a',
#  'noble',
#  'town.',
#  'It',
#  'is',
#  'now',
#  'a',
#  'good',
#  'sea-port,',
#  'and',
#  'neatly',
#  'built',
#  'enough,',
#  'and',
#  'has',
#  'a',
#  'bridge',
#  'of',
#  'thirty-two',
#  'arches.',
#  'Here',
#  'is',
#  'a',
#  'famous',
#  'ancient',
#  'Greek',
#  'church.',
#  'I',
#  'had',
#  'given',
#  'one',
#  'of',
#  'my',
#  'coaches',
#  'to',
#  'a',
#  'Greek',
#  'lady,',
#  'who',
#  'desired',
#  'the',
#  'conveniency',
#  'of',
#  'travelling',
#  'with',
#  'me;',
#  'she',
#  'designed',
#  'to',
#  'pay',
#  'her',
#  'devotions,',
#  'and',
#  'I',
#  'was',
#  'glad',
#  'of',
#  'the',
#  'opportunity',
#  'of',
#  'going',
#  'with',
#  'her.',
#  'I',
#  'found',
#  'it',
#  'an',
#  'ill-built',
#  'edifice,',
#  'set',
#  'out',
#  'with',
#  'the',
#  'same',
#  'sort',
#  'of',
#  'ornaments,',
#  'but',
#  'less',
#  'rich,',
#  'as',
#  'the',
#  'Roman-catholic',
#  'churches.',
#  'They',
#  'shewed',
#  'me',
#  'a',
#  "saint's",
#  'body,',
#  'where',
#  'I',
#  'threw',
#  'a',
#  'piece',
#  'of',
#  'money;',
#  'and',
#  'a',
#  'picture',
#  'of',
#  'the',
#  'virgin',
#  'Mary,',
#  'drawn',
#  'by',
#  'the',
#  'hand',
#  'of',
#  'St',
#  'Luke,',
#  'very',
#  'little',
#  'to',
#  'the',
#  'credit',
#  'of',
#  'his',
#  'painting;',
#  'but,',
#  'however,',
#  'the',
#  'finest',
#  'Madona',
#  '(sic)',
#  'of',
#  'Italy,',
#  'is',
#  'not',
#  'more',
#  'famous',
#  'for',
#  'her',
#  'miracles.',
#  'The',
#  'Greeks',
#  'have',
#  'a',
#  'monstrous',
#  'taste',
#  'in',
#  'their',
#  'pictures,',
#  'which,',
#  'for',
#  'more',
#  'finery,',
#  'are',
#  'always',
#  'drawn',
#  'upon',
#  'a',
#  'gold',
#  'ground.',
#  'You',
#  'may',
#  'imagine',
#  'what',
#  'a',
#  'good',
#  'air',
#  'this',
#  'has;',
#  'but',
#  'they',
#  'have',
#  'no',
#  'notion,',
#  'either',
#  'of',
#  'shade',
#  'or',
#  'proportion.',
#  'They',
#  'have',
#  'a',
#  'bishop',
#  'here,',
#  'who',
#  'officiated',
#  'in',
#  'his',
#  'purple',
#  'robe,',
#  'and',
#  'sent',
#  'me',
#  'a',
#  'candle',
#  'almost',
#  'as',
#  'big',
#  'as',
#  'myself',
#  'for',
#  'a',
#  'present,',
#  'when',
#  'I',
#  'was',
#  'at',
#  'my',
#  'lodging.',
#  'We',
#  'lay',
#  'that',
#  'night',
#  'at',
#  'a',
#  'town',
#  'called',
#  'Bujuk',
#  'Cekmege,',
#  'or',
#  'Great',
#  'Bridge;',
#  'and',
#  'the',
#  'night',
#  'following,',
#  'at',
#  'Kujuk',
#  'Cekmege,',
#  'or',
#  'Little',
#  'Bridge;',
#  'in',
#  'a',
#  'very',
#  'pleasant',
#  'lodging,',
#  'formerly',
#  'a',
#  'monastery',
#  'of',
#  'dervises;',
#  'having',
#  'before',
#  'it',
#  'a',
#  'large',
#  'court,',
#  'encompassed',
#  'with',
#  'marble',
#  'cloisters,',
#  'with',
#  'a',
#  'good',
#  'fountain',
#  'in',
#  'the',
#  'middle.',
#  'The',
#  'prospect',
#  'from',
#  'this',
#  'place,',
#  'and',
#  'the',
#  'gardens',
#  'round',
#  'it,',
#  'is',
#  'the',
#  'most',
#  'agreeable',
#  'I',
#  'have',
#  'seen;',
#  'and',
#  'shews,',
#  'that',
#  'monks',
#  'of',
#  'all',
#  'religions',
#  'know',
#  'how',
#  'to',
#  'chuse',
#  'their',
#  'retirements.',
#  "'Tis",
#  'now',
#  'belonging',
#  'to',
#  'a',
#  '_hogia_',
#  'or',
#  'schoolmaster,',
#  'who',
#  'teaches',
#  'boys',
#  'here.',
#  'I',
#  'asked',
#  'him',
#  'to',
#  'shew',
#  'me',
#  'his',
#  'own',
#  'apartment,',
#  'and',
#  'was',
#  'surprised',
#  'to',
#  'see',
#  'him',
#  'point',
#  'to',
#  'a',
#  'tall',
#  'cypress',
#  'tree',
#  'in',
#  'the',
#  'garden,',
#  'on',
#  'the',
#  'top',
#  'of',
#  'which',
#  'was',
#  'a',
#  'place',
#  'for',
#  'a',
#  'bed',
#  'for',
#  'himself,',
#  'and',
#  'a',
#  'little',
#  'lower,',
#  'one',
#  'for',
#  'his',
#  'wife',
#  'and',
#  'two',
#  'children,',
#  'who',
#  'slept',
#  'there',
#  'every',
#  'night.',
#  'I',
#  'was',
#  'so',
#  'much',
#  'diverted',
#  'with',
#  'the',
#  'fancy,',
#  'I',
#  'resolved',
#  'to',
#  'examine',
#  'his',
#  'nest',
#  'nearer;',
#  'but',
#  'after',
#  'going',
#  'up',
#  'fifty',
#  'steps,',
#  'I',
#  'found',
#  'I',
#  'had',
#  'still',
#  'fifty',
#  'to',
#  'go',
#  'up,',
#  'and',
#  'then',
#  'I',
#  'must',
#  'climb',
#  'from',
#  'branch',
#  'to',
#  'branch,',
#  'with',
#  'some',
#  'hazard',
#  'of',
#  'my',
#  'neck.',
#  'I',
#  'thought',
#  'it',
#  'therefore',
#  'the',
#  'best',
#  'way',
#  'to',
#  'come',
#  'down',
#  'again.',
#  'WE',
#  'arrived',
#  'the',
#  'next',
#  'day',
#  'at',
#  'Constantinople;',
#  'but',
#  'I',
#  'can',
#  'yet',
#  'tell',
#  'you',
#  'very',
#  'little',
#  'of',
#  'it,',
#  'all',
#  'my',
#  'time',
#  'having',
#  'been',
#  'taken',
#  'up',
#  'with',
#  'receiving',
#  'visits,',
#  'which',
#  'are,',
#  'at',
#  'least,',
#  'a',
#  'very',
#  'good',
#  'entertainment',
#  'to',
#  'the',
#  'eyes,',
#  'the',
#  'young',
#  'women',
#  'being',
#  'all',
#  'beauties,',
#  'and',
#  'their',
#  'beauty',
#  'highly',
#  'improved',
#  'by',
#  'the',
#  'high',
#  'taste',
#  'of',
#  'their',
#  'dress.',
#  'Our',
#  'palace',
#  'is',
#  'in',
#  'Pera,',
#  'which',
#  'is',
#  'no',
#  'more',
#  'a',
#  'suburb',
#  'of',
#  'Constantinople,',
#  'than',
#  'Westminster',
#  'is',
#  'a',
#  'suburb',
#  'to',
#  'London.',
#  'All',
#  'the',
#  'ambassadors',
#  'are',
#  'lodged',
#  'very',
#  'near',
#  'each',
#  'other.',
#  'One',
#  'part',
#  'of',
#  'our',
#  'house',
#  'shews',
#  'us',
#  'the',
#  'port,',
#  'the',
#  'city,',
#  'and',
#  'the',
#  'seraglio,',
#  'and',
#  'the',
#  'distant',
#  'hills',
#  'of',
#  'Asia;',
#  'perhaps,',
#  'all',
#  'together,',
#  'the',
#  'most',
#  'beautiful',
#  'prospect',
#  'in',
#  'the',
#  'world.',
#  'A',
#  'CERTAIN',
#  'French',
#  'author',
#  'says,',
#  'Constantinople',
#  'is',
#  'twice',
#  'as',
#  'big',
#  'as',
#  'Paris.',
#  'Mr',
#  'W----y',
#  'is',
#  'unwilling',
#  'to',
#  'own',
#  "'tis",
#  'bigger',
#  'than',
#  'London,',
#  'though',
#  'I',
#  'confess',
#  'it',
#  'appears',
#  'to',
#  'me',
#  'to',
#  'be',
#  'so;',
#  'but',
#  'I',
#  "don't",
#  'believe',
#  'it',
#  'is',
#  'so',
#  'populous.',
#  'The',
#  'burying',
#  'fields',
#  'about',
#  'it',
#  'are',
#  'certainly',
#  'much',
#  'larger',
#  'than',
#  'the',
#  'whole',
#  'city.',
#  "'Tis",
#  'surprising',
#  'what',
#  'a',
#  'vast',
#  'deal',
#  'of',
#  'land',
#  'is',
#  'lost',
#  'this',
#  'way',
#  'in',
#  'Turkey.',
#  'Sometimes',
#  'I',
#  'have',
#  'seen',
#  'burying',
#  'places',
#  'of',
#  'several',
#  'miles,',
#  'belonging',
#  'to',
#  'very',
#  'inconsiderable',
#  'villages,',
#  'which',
#  'were',
#  'formerly',
#  'great',
#  'towns,',
#  'and',
#  'retain',
#  'no',
#  'other',
#  'mark',
#  'of',
#  'their',
#  'ancient',
#  'grandeur,',
#  'than',
#  'this',
#  'dismal',
#  'one.',
#  'On',
#  'no',
#  'occasion',
#  'do',
#  'they',
#  'ever',
#  'remove',
#  'a',
#  'stone',
#  'that',
#  'serves',
#  'for',
#  'a',
#  'monument.',
#  'Some',
#  'of',
#  'them',
#  'are',
#  'costly',
#  'enough,',
#  'being',
#  'of',
#  'very',
#  'fine',
#  'marble.',
#  'They',
#  'set',
#  'up',
#  'a',
#  'pillar,',
#  'with',
#  'a',
#  'carved',
#  'turbant',
#  'on',
#  'the',
#  'top',
#  'of',
#  'it,',
#  'to',
#  'the',
#  'memory',
#  'of',
#  'a',
#  'man;',
#  'and',
#  'as',
#  'the',
#  'turbants,',
#  'by',
#  'their',
#  'different',
#  'shapes,',
#  'shew',
#  'the',
#  'quality',
#  'or',
#  'profession,',
#  "'tis",
#  'in',
#  'a',
#  'manner',
#  'putting',
#  'up',
#  'the',
#  'arms',
#  'of',
#  'the',
#  'deceased;',
#  'besides,',
#  'the',
#  'pillar',
#  'commonly',
#  'bears',
#  'an',
#  'inscription',
#  'in',
#  'gold',
#  'letters.',
#  'The',
#  'ladies',
#  'have',
#  'a',
#  'simple',
#  'pillar',
#  'without',
#  'other',
#  'ornament,',
#  'except',
#  'those',
#  'that',
#  'die',
#  'unmarried,',
#  'who',
#  'have',
#  'a',
#  ...]

# %%
# looking good! let's actually assign it to a variable

words = letter_35.split()

# %% [markdown]
# Not the best variable name, but it does the job!
#
# Let's investigate further

# %%
# let's look at this one common word:
words[50]
# Out:
# 'them.'

# %% [markdown]
# See, .split() did not remove punctuation, which means:

# %%
words.index("them")
# Out:
# 205

# %%
words.index("them,")
# Out:
# 1186

# %%
words.count("them")
# Out:
# 7

# %% [markdown]
# Since our goals is to count words, we need to normalize `them` a little. We have several different versions of essentially the same word.
#
# Text normalization is the process of transforming text into a consistent, standardized form so that all forms of the word are all counted as the same word. Common steps include *lowercasing*, *removing punctuation*, and *stripping extra whitespace*.

# %% [markdown]
# ### 🥊 Challenge 5: Remove Punctuation
#
# Hint: We just did something very similar!

# %%
### YOUR CODE HERE

# %% [markdown]
# Here is how I would remove punctuation:
#
# `LOOK AT MY CODE AND TELL ME HOW I DID IT`

# %%
words_clean = [word.strip(string.punctuation) for word in words]

# %%
words_clean.index("them,")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 words_clean.index("them,")
#
# ValueError: list.index(x): x not in list

# %%
words_clean.count("them")
# Out:
# 14

# %% [markdown]
# ### 🥊 Challenge 6: Lowercase everything
#
# While we are at it, let's lowercase everything too

# %%
##  YOUR CODE HERE

# %% [markdown]
# Here is how I would remove punctuation:
#
# `LOOK AT MY CODE AND TELL ME HOW I DID IT`

# %%
words_extra_clean = []

for word in words_clean:
    words_extra_clean.append(word.lower())

print(words_extra_clean[:50])
# Out:
# ['i', 'have', 'had', 'the', 'advantage', 'of', 'very', 'fine', 'weather', 'all', 'my', 'journey', 'and', 'as', 'the', 'summer', 'is', 'now', 'in', 'its', 'beauty', 'i', 'enjoyed', 'the', 'pleasure', 'of', 'fine', 'prospects', 'and', 'the', 'meadows', 'being', 'full', 'of', 'all', 'sorts', 'of', 'garden', 'flowers', 'and', 'sweet', 'herbs', 'my', 'berlin', 'perfumed', 'the', 'air', 'as', 'it', 'pressed']

# %%
# Let's compare the counts for a very common word: the

print("Number of 'the' in words_clean:", words_clean.count("the"))

print("Number of 'the' in words_EXTRA_clean:", words_extra_clean.count("the"))
# Out:
# Number of 'the' in words_clean: 91
# Number of 'the' in words_EXTRA_clean: 100

# %% [markdown]
# <mark style="background: rgba(167, 139, 250, 0.3); color: inherit; border-radius: 3px; padding: 0 2px;">Now, we can continue with our slightly humourously titled words_extra_clean list or we can actually apply the transformations that we are happy with back to our original list, words.</mark>

# %%
# remember that we can chain functions!

words = [word.strip(string.punctuation).lower() for word in words]

words[:50]
# Out:
# ['i',
#  'have',
#  'had',
#  'the',
#  'advantage',
#  'of',
#  'very',
#  'fine',
#  'weather',
#  'all',
#  'my',
#  'journey',
#  'and',
#  'as',
#  'the',
#  'summer',
#  'is',
#  'now',
#  'in',
#  'its',
#  'beauty',
#  'i',
#  'enjoyed',
#  'the',
#  'pleasure',
#  'of',
#  'fine',
#  'prospects',
#  'and',
#  'the',
#  'meadows',
#  'being',
#  'full',
#  'of',
#  'all',
#  'sorts',
#  'of',
#  'garden',
#  'flowers',
#  'and',
#  'sweet',
#  'herbs',
#  'my',
#  'berlin',
#  'perfumed',
#  'the',
#  'air',
#  'as',
#  'it',
#  'pressed']

# %% [markdown]
# ### 🥊 Challenge 7: Find unique words

# %%
## YOUR CODE HERE

# %%
# Remember sets?

unique_words = set(words)

unique_words
# Out:
# {'a',
#  'about',
#  'acceptable',
#  'admitted',
#  'advantage',
#  'afraid',
#  'after',
#  'again',
#  'agreeable',
#  'air',
#  'aleppo',
#  'all',
#  'almost',
#  'already',
#  'always',
#  'am',
#  'ambassadors',
#  'an',
#  'ancient',
#  'anciently',
#  'and',
#  'another',
#  'antiquaries',
#  'antiquity',
#  'any',
#  'apartment',
#  'apartments',
#  'appears',
#  'appointed',
#  'arabia',
#  'arches',
#  'are',
#  'arms',
#  'arrived',
#  'as',
#  'asia',
#  'asked',
#  'assured',
#  'at',
#  'augustine',
#  'author',
#  'back',
#  'baggage',
#  'be',
#  'bears',
#  'beauties',
#  'beautiful',
#  'beauty',
#  'bed',
#  'been',
#  'befel',
#  'before',
#  'being',
#  'belief',
#  'believe',
#  'believed',
#  'belonging',
#  'beloved',
#  'berlin',
#  'besides',
#  'bespoke',
#  'best',
#  'big',
#  'bigger',
#  'bishop',
#  'bliss',
#  'body',
#  'boys',
#  'branch',
#  'bridge',
#  'bringing',
#  'built',
#  'bujuk',
#  'burning',
#  'burying',
#  'but',
#  'by',
#  'c',
#  'cairo',
#  'called',
#  'calling',
#  'can',
#  'candle',
#  'cannot',
#  'care',
#  'carved',
#  'cekmege',
#  'celestial',
#  'certain',
#  'certainly',
#  'children',
#  'chose',
#  'church',
#  'churches',
#  'chuse',
#  'ciorlei',
#  'cities',
#  'city',
#  'climb',
#  'cloisters',
#  'close',
#  'coaches',
#  'collection',
#  'come',
#  'coming',
#  'commerce',
#  'committed',
#  'commonly',
#  'conac',
#  'confess',
#  'confinement',
#  'confirm',
#  'considerable',
#  'constantinople',
#  'constantly',
#  'content',
#  'conveniency',
#  'conversation',
#  'correspondents',
#  'costly',
#  'could',
#  'country',
#  'court',
#  'covered',
#  'creation',
#  'creature',
#  'credit',
#  'crucifix',
#  'curiosity',
#  'cut',
#  'cypress',
#  'dare',
#  'day',
#  'days',
#  'deal',
#  'deceased',
#  'depart',
#  'depended',
#  'depending',
#  'dervises',
#  'designed',
#  'desired',
#  'desires',
#  'destined',
#  'determine',
#  'devotions',
#  'die',
#  'dies',
#  'different',
#  'dismal',
#  'distant',
#  'distiches',
#  'diverted',
#  'divinity',
#  'divorced',
#  'do',
#  'doctrine',
#  'does',
#  "don't",
#  'down',
#  'drawn',
#  'dress',
#  'dying',
#  'each',
#  'easily',
#  'edifice',
#  'either',
#  'elevated',
#  'empire',
#  'employed',
#  'encompassed',
#  'end',
#  'english',
#  'enhance',
#  'enjoyed',
#  'enough',
#  'enquire',
#  'entertained',
#  'entertainment',
#  'equipages',
#  'eternal',
#  'ever',
#  'every',
#  'examination',
#  'examine',
#  'examples',
#  'except',
#  'expects',
#  'explain',
#  'extraordinary',
#  'eyes',
#  'face',
#  'families',
#  'famous',
#  'fancied',
#  'fancy',
#  'fear',
#  'fields',
#  'fifty',
#  'figure',
#  'find',
#  'fine',
#  'finely',
#  'finery',
#  'finest',
#  'fit',
#  'five',
#  'flowers',
#  'following',
#  'for',
#  'forgot',
#  'formerly',
#  'forth',
#  'found',
#  'fountain',
#  'fountains',
#  'french',
#  'fresh',
#  'from',
#  'full',
#  'furnished',
#  'garden',
#  'gardens',
#  'gave',
#  'generally',
#  'get',
#  'given',
#  'glad',
#  'go',
#  'god',
#  'goes',
#  'going',
#  'gold',
#  'good',
#  'got',
#  'grand',
#  'grandeur',
#  'great',
#  'greek',
#  'greeks',
#  'ground',
#  'grove',
#  'grown',
#  'guessed',
#  'had',
#  'hand',
#  'hands',
#  'happiness',
#  'has',
#  'have',
#  'having',
#  'hazard',
#  'he',
#  'head',
#  'heads',
#  'heaps',
#  'hear',
#  'heart',
#  'her',
#  'herbs',
#  'here',
#  'high',
#  'highly',
#  'hills',
#  'him',
#  'himself',
#  'his',
#  'hogia',
#  'holding',
#  'hope',
#  'house',
#  'houses',
#  'how',
#  'however',
#  'i',
#  'if',
#  'ill',
#  'ill-built',
#  'image',
#  'imagine',
#  'improved',
#  'in',
#  'inconsiderable',
#  'increase',
#  'indeed',
#  'inferior',
#  'inscription',
#  'interest',
#  'interpreter',
#  'into',
#  'is',
#  'it',
#  'italy',
#  'its',
#  'journey',
#  'kettles',
#  'kind',
#  'king',
#  'kings',
#  'know',
#  'knowing',
#  'knows',
#  'kujuk',
#  'ladies',
#  'lady',
#  'lamps',
#  'land',
#  'large',
#  'larger',
#  'law',
#  'lay',
#  'learned',
#  'least',
#  'leave',
#  'less',
#  'letters',
#  'liberty',
#  'life',
#  'like',
#  'literally',
#  'little',
#  'lively',
#  'lodge',
#  'lodged',
#  'lodging',
#  'london',
#  'looked',
#  'lost',
#  'lower',
#  'luke',
#  'ly',
#  'macedonian',
#  'made',
#  'madona',
#  'man',
#  'manner',
#  'many',
#  'marble',
#  'mark',
#  'marmora',
#  'marrying',
#  'mary',
#  'may',
#  'me',
#  'meadows',
#  'medals',
#  'melt',
#  'memory',
#  'men',
#  'mention',
#  'middle',
#  'midst',
#  'miles',
#  'mine',
#  'miracles',
#  'misfortune',
#  'mistake',
#  'monastery',
#  'money',
#  'monks',
#  'monstrous',
#  'monument',
#  'more',
#  'most',
#  'mr',
#  'much',
#  'multiply',
#  'mummy',
#  'must',
#  'my',
#  'myself',
#  'mystically',
#  'names',
#  'near',
#  'nearer',
#  'neatly',
#  'neck',
#  'nest',
#  'never',
#  'next',
#  'night',
#  'no',
#  'noble',
#  'not',
#  'nothing',
#  'notion',
#  'notwithstanding',
#  'now',
#  'occasion',
#  'odd',
#  'of',
#  'offered',
#  'officiated',
#  'often',
#  'old',
#  'on',
#  'one',
#  'ones',
#  'only',
#  'opportunity',
#  'or',
#  'order',
#  'ornament',
#  'ornaments',
#  'other',
#  'our',
#  'out',
#  'own',
#  'painted',
#  'painting',
#  'palace',
#  'palestine',
#  'pallas',
#  'pans',
#  'paradise',
#  'paris',
#  'part',
#  'particular',
#  'particularities',
#  'particularly',
#  'pass',
#  'passed',
#  'pay',
#  'pencils',
#  'pera',
#  'perfumed',
#  'perhaps',
#  'permit',
#  'permitted',
#  'permitting',
#  'perpetual',
#  'perseus',
#  'picture',
#  'pictures',
#  'piece',
#  'pillar',
#  'place',
#  'places',
#  'planted',
#  'pleasant',
#  'pleasure',
#  'point',
#  'populous',
#  'port',
#  'present',
#  'pressed',
#  'pretend',
#  'price',
#  'prisoner',
#  'professed',
#  'profession',
#  'progress',
#  'project',
#  'properly',
#  'prophecies',
#  'prophyry',
#  'propontis',
#  'proportion',
#  'prospect',
#  'prospects',
#  'public',
#  'purple',
#  'putting',
#  'qualities',
#  'quality',
#  'railed',
#  'rather',
#  'rational',
#  'read',
#  'ready',
#  'reason',
#  'receiving',
#  'release',
#  'religion',
#  'religions',
#  'remain',
#  'remained',
#  'remarkable',
#  'remembered',
#  'remove',
#  'represents',
#  'reprobate',
#  'reprobation',
#  'resolved',
#  'rest',
#  'retain',
#  'retirements',
#  'return',
#  'reverse',
#  'rich',
#  'road',
#  'robe',
#  'roman-catholic',
#  'rose',
#  'round',
#  'safe',
#  'saint',
#  "saint's",
#  'same',
#  'sardonyx',
#  'say',
#  'says',
#  'schoolmaster',
#  'sculpture',
#  'sea',
#  'sea-port',
#  'see',
#  'seek',
#  'seemed',
#  'seen',
#  'selivrea',
#  'sell',
#  'send',
#  'sent',
#  'sepulchres',
#  'seraglio',
#  'serve',
#  'serves',
#  'set',
#  'seven',
#  'several',
#  'shade',
#  'shall',
#  'shapes',
#  'she',
#  'shew',
#  'shewed',
#  'shewing',
#  'shews',
#  'shuts',
#  'sic',
#  'side',
#  'signior',
#  'simple',
#  'since',
#  'sir',
#  'skill',
#  'slaves',
#  'slept',
#  'so',
#  'socrates',
#  'solemn',
#  'some',
#  'sometimes',
#  'sort',
#  'sorts',
#  'souls',
#  'spahis',
#  'spoke',
#  'st',
#  'stare',
#  'state',
#  'steps',
#  'still',
#  'stone',
#  'submitted',
#  'suburb',
#  'sultans',
#  'summer',
#  'superstitious',
#  'suppose',
#  'surprised',
#  'surprising',
#  'sweden',
#  'sweet',
#  'take',
#  'taken',
#  'taking',
#  'tall',
#  'taste',
#  'teaches',
#  'tell',
#  'ten',
#  'tents',
#  'terms',
#  'than',
#  'that',
#  "that's",
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'theology',
#  'there',
#  'therefore',
#  'these',
#  'they',
#  'thick',
#  'thing',
#  'thirty',
#  'thirty-two',
#  'this',
#  'those',
#  'though',
#  'thought',
#  'threw',
#  'through',
#  'thus',
#  'till',
#  'time',
#  'tis',
#  'title',
#  'to',
#  'together',
#  'took',
#  'top',
#  'towers',
#  'town',
#  'towns',
#  'trade',
#  'translation',
#  'travel',
#  'travelling',
#  'tree',
#  'trees',
#  'trouble',
#  'true',
#  'try',
#  'turbant',
#  'turbants',
#  'turkey',
#  'turkish',
#  'turks',
#  'turned',
#  'twice',
#  'two',
#  'under',
#  'unmarried',
#  'unwilling',
#  'up',
#  'upon',
#  'us',
#  'use',
#  'useless',
#  'valuable',
#  'value',
#  'vast',
#  'verse',
#  'very',
#  'victory',
#  'view',
#  'villages',
#  'virgin',
#  'virginity',
#  'virtues',
#  'visits',
#  'vow',
#  'vulgar',
#  'w----y',
#  'waggons',
#  'walls',
#  'war',
#  'was',
#  'way',
#  'we',
#  'weather',
#  'well',
#  'were',
#  'westminster',
#  'what',
#  'when',
#  'where',
#  'which',
#  'who',
#  'whole',
#  'widows',
#  'wife',
#  'will',
#  'with',
#  'within',
#  'without',
#  'woman',
#  'women',
#  'works',
#  'world',
#  'wrote',
#  'yet',
#  'you',
#  'young',
#  "your's"}

# %%
len(unique_words)
# Out:
# 681

# %% [markdown]
# ### 🥊 Challenge 8: Count unique words

# %%
### YOUR CODE HERE

# %%
# Remember Counter()

unique_word_counts = Counter(words)

unique_word_counts
# Out:
# Counter({'the': 100,
#          'of': 88,
#          'a': 61,
#          'to': 49,
#          'i': 45,
#          'and': 40,
#          'in': 30,
#          'is': 23,
#          'it': 22,
#          'that': 21,
#          'are': 21,
#          'have': 20,
#          'they': 20,
#          'with': 18,
#          'for': 18,
#          'their': 17,
#          'very': 15,
#          'all': 15,
#          'but': 15,
#          'them': 14,
#          'my': 12,
#          'not': 12,
#          'which': 12,
#          'was': 12,
#          'me': 12,
#          'who': 12,
#          'this': 11,
#          'as': 10,
#          'at': 10,
#          'when': 9,
#          'his': 9,
#          'one': 9,
#          'some': 9,
#          'we': 8,
#          'you': 8,
#          'her': 8,
#          'or': 7,
#          'little': 7,
#          'by': 7,
#          'on': 7,
#          'so': 7,
#          'than': 7,
#          'those': 7,
#          'great': 6,
#          'no': 6,
#          'from': 6,
#          'tis': 6,
#          'can': 6,
#          'other': 6,
#          'be': 6,
#          'had': 5,
#          'fine': 5,
#          'our': 5,
#          'there': 5,
#          'he': 5,
#          'most': 5,
#          'night': 5,
#          'good': 5,
#          'greek': 5,
#          'more': 5,
#          'upon': 5,
#          'up': 5,
#          'any': 5,
#          'women': 4,
#          'found': 4,
#          'out': 4,
#          'way': 4,
#          'will': 4,
#          'where': 4,
#          'were': 4,
#          'him': 4,
#          'into': 4,
#          'has': 4,
#          'here': 4,
#          'body': 4,
#          'man': 4,
#          'now': 3,
#          'beauty': 3,
#          'being': 3,
#          'grand': 3,
#          'nothing': 3,
#          'made': 3,
#          'see': 3,
#          'several': 3,
#          'much': 3,
#          'come': 3,
#          'ancient': 3,
#          'bridge': 3,
#          'famous': 3,
#          'she': 3,
#          'an': 3,
#          'piece': 3,
#          'sic': 3,
#          'place': 3,
#          'own': 3,
#          'point': 3,
#          'top': 3,
#          'must': 3,
#          'again': 3,
#          'constantinople': 3,
#          'city': 3,
#          'about': 3,
#          'pillar': 3,
#          'without': 3,
#          'true': 3,
#          'state': 3,
#          'only': 3,
#          'god': 3,
#          'hope': 3,
#          'medals': 3,
#          'journey': 2,
#          'meadows': 2,
#          'full': 2,
#          'garden': 2,
#          'air': 2,
#          'signior': 2,
#          'us': 2,
#          'covered': 2,
#          'coaches': 2,
#          'road': 2,
#          'asia': 2,
#          'always': 2,
#          'villages': 2,
#          'seraglio': 2,
#          'built': 2,
#          'goes': 2,
#          'destined': 2,
#          'ladies': 2,
#          'court': 2,
#          'trees': 2,
#          'surprised': 2,
#          'almost': 2,
#          'though': 2,
#          'lost': 2,
#          'world': 2,
#          'lodged': 2,
#          'lay': 2,
#          'next': 2,
#          'town': 2,
#          'enough': 2,
#          'designed': 2,
#          'going': 2,
#          'set': 2,
#          'same': 2,
#          'virgin': 2,
#          'drawn': 2,
#          'hand': 2,
#          'greeks': 2,
#          'taste': 2,
#          'gold': 2,
#          'imagine': 2,
#          'what': 2,
#          'notion': 2,
#          'big': 2,
#          'present': 2,
#          'lodging': 2,
#          'cekmege': 2,
#          'formerly': 2,
#          'having': 2,
#          'marble': 2,
#          'prospect': 2,
#          'round': 2,
#          'seen': 2,
#          'shews': 2,
#          'know': 2,
#          'how': 2,
#          'belonging': 2,
#          'teaches': 2,
#          'shew': 2,
#          'wife': 2,
#          'two': 2,
#          'children': 2,
#          'fancy': 2,
#          'after': 2,
#          'fifty': 2,
#          'branch': 2,
#          'therefore': 2,
#          'best': 2,
#          'yet': 2,
#          'tell': 2,
#          'beauties': 2,
#          'suburb': 2,
#          'london': 2,
#          "don't": 2,
#          'believe': 2,
#          'burying': 2,
#          'certainly': 2,
#          'occasion': 2,
#          'ever': 2,
#          'monument': 2,
#          'different': 2,
#          'manner': 2,
#          'die': 2,
#          'unmarried': 2,
#          'men': 2,
#          'religion': 2,
#          'pass': 2,
#          'woman': 2,
#          'looked': 2,
#          'souls': 2,
#          'dying': 2,
#          'themselves': 2,
#          'antiquaries': 2,
#          'face': 2,
#          'valuable': 2,
#          'head': 2,
#          'find': 2,
#          'price': 2,
#          'saint': 2,
#          'gave': 2,
#          'mummy': 2,
#          'considerable': 2,
#          'c': 2,
#          'advantage': 1,
#          'weather': 1,
#          'summer': 1,
#          'its': 1,
#          'enjoyed': 1,
#          'pleasure': 1,
#          'prospects': 1,
#          'sorts': 1,
#          'flowers': 1,
#          'sweet': 1,
#          'herbs': 1,
#          'berlin': 1,
#          'perfumed': 1,
#          'pressed': 1,
#          'furnished': 1,
#          'thirty': 1,
#          'waggons': 1,
#          'baggage': 1,
#          'five': 1,
#          'country': 1,
#          'spahis': 1,
#          'equipages': 1,
#          'coming': 1,
#          'war': 1,
#          'travel': 1,
#          'tents': 1,
#          'chose': 1,
#          'ly': 1,
#          'houses': 1,
#          'trouble': 1,
#          'names': 1,
#          'passed': 1,
#          'remarkable': 1,
#          'ciorlei': 1,
#          'conac': 1,
#          'use': 1,
#          'curiosity': 1,
#          'view': 1,
#          'apartments': 1,
#          'midst': 1,
#          'thick': 1,
#          'grove': 1,
#          'fresh': 1,
#          'fountains': 1,
#          'walls': 1,
#          'distiches': 1,
#          'turkish': 1,
#          'verse': 1,
#          'wrote': 1,
#          'pencils': 1,
#          'interpreter': 1,
#          'explain': 1,
#          'well': 1,
#          'turned': 1,
#          'easily': 1,
#          'believed': 1,
#          'translation': 1,
#          'literally': 1,
#          'thus': 1,
#          'english': 1,
#          'lodge': 1,
#          'depart': 1,
#          'never': 1,
#          "that's": 1,
#          'within': 1,
#          'heart': 1,
#          'rest': 1,
#          'through': 1,
#          'painted': 1,
#          'side': 1,
#          'sea': 1,
#          'marmora': 1,
#          'propontis': 1,
#          'selivrea': 1,
#          'anciently': 1,
#          'noble': 1,
#          'sea-port': 1,
#          'neatly': 1,
#          'thirty-two': 1,
#          'arches': 1,
#          'church': 1,
#          'given': 1,
#          'lady': 1,
#          'desired': 1,
#          'conveniency': 1,
#          'travelling': 1,
#          'pay': 1,
#          'devotions': 1,
#          'glad': 1,
#          'opportunity': 1,
#          'ill-built': 1,
#          'edifice': 1,
#          'sort': 1,
#          'ornaments': 1,
#          'less': 1,
#          'rich': 1,
#          'roman-catholic': 1,
#          'churches': 1,
#          'shewed': 1,
#          "saint's": 1,
#          'threw': 1,
#          'money': 1,
#          'picture': 1,
#          'mary': 1,
#          'st': 1,
#          'luke': 1,
#          'credit': 1,
#          'painting': 1,
#          'however': 1,
#          'finest': 1,
#          'madona': 1,
#          'italy': 1,
#          'miracles': 1,
#          'monstrous': 1,
#          'pictures': 1,
#          'finery': 1,
#          'ground': 1,
#          'may': 1,
#          'either': 1,
#          'shade': 1,
#          'proportion': 1,
#          'bishop': 1,
#          'officiated': 1,
#          'purple': 1,
#          'robe': 1,
#          'sent': 1,
#          'candle': 1,
#          'myself': 1,
#          'called': 1,
#          'bujuk': 1,
#          'following': 1,
#          'kujuk': 1,
#          'pleasant': 1,
#          'monastery': 1,
#          'dervises': 1,
#          'before': 1,
#          'large': 1,
#          'encompassed': 1,
#          'cloisters': 1,
#          'fountain': 1,
#          'middle': 1,
#          'gardens': 1,
#          'agreeable': 1,
#          'monks': 1,
#          'religions': 1,
#          'chuse': 1,
#          'retirements': 1,
#          'hogia': 1,
#          'schoolmaster': 1,
#          'boys': 1,
#          'asked': 1,
#          'apartment': 1,
#          'tall': 1,
#          'cypress': 1,
#          'tree': 1,
#          'bed': 1,
#          'himself': 1,
#          'lower': 1,
#          'slept': 1,
#          'every': 1,
#          'diverted': 1,
#          'resolved': 1,
#          'examine': 1,
#          'nest': 1,
#          'nearer': 1,
#          'steps': 1,
#          'still': 1,
#          'go': 1,
#          'then': 1,
#          'climb': 1,
#          'hazard': 1,
#          'neck': 1,
#          'thought': 1,
#          'down': 1,
#          'arrived': 1,
#          'day': 1,
#          'time': 1,
#          'been': 1,
#          'taken': 1,
#          'receiving': 1,
#          'visits': 1,
#          'least': 1,
#          'entertainment': 1,
#          'eyes': 1,
#          'young': 1,
#          'highly': 1,
#          'improved': 1,
#          'high': 1,
#          'dress': 1,
#          'palace': 1,
#          'pera': 1,
#          'westminster': 1,
#          'ambassadors': 1,
#          'near': 1,
#          'each': 1,
#          'part': 1,
#          'house': 1,
#          'port': 1,
#          'distant': 1,
#          'hills': 1,
#          'perhaps': 1,
#          'together': 1,
#          'beautiful': 1,
#          'certain': 1,
#          'french': 1,
#          'author': 1,
#          'says': 1,
#          'twice': 1,
#          'paris': 1,
#          'mr': 1,
#          'w----y': 1,
#          'unwilling': 1,
#          'bigger': 1,
#          'confess': 1,
#          'appears': 1,
#          'populous': 1,
#          'fields': 1,
#          'larger': 1,
#          'whole': 1,
#          'surprising': 1,
#          'vast': 1,
#          'deal': 1,
#          'land': 1,
#          'turkey': 1,
#          'sometimes': 1,
#          'places': 1,
#          'miles': 1,
#          'inconsiderable': 1,
#          'towns': 1,
#          'retain': 1,
#          'mark': 1,
#          'grandeur': 1,
#          'dismal': 1,
#          'do': 1,
#          'remove': 1,
#          'stone': 1,
#          'serves': 1,
#          'costly': 1,
#          'carved': 1,
#          'turbant': 1,
#          'memory': 1,
#          'turbants': 1,
#          'shapes': 1,
#          'quality': 1,
#          'profession': 1,
#          'putting': 1,
#          'arms': 1,
#          'deceased': 1,
#          'besides': 1,
#          'commonly': 1,
#          'bears': 1,
#          'inscription': 1,
#          'letters': 1,
#          'simple': 1,
#          'ornament': 1,
#          'except': 1,
#          'rose': 1,
#          'sepulchres': 1,
#          'particular': 1,
#          'families': 1,
#          'railed': 1,
#          'planted': 1,
#          'sultans': 1,
#          'lamps': 1,
#          'constantly': 1,
#          'burning': 1,
#          'spoke': 1,
#          'forgot': 1,
#          'mention': 1,
#          'particularities': 1,
#          'read': 1,
#          'seemed': 1,
#          'odd': 1,
#          'could': 1,
#          'divorced': 1,
#          'solemn': 1,
#          'take': 1,
#          'terms': 1,
#          'permitting': 1,
#          'another': 1,
#          'examples': 1,
#          'submitted': 1,
#          'law': 1,
#          'rather': 1,
#          'back': 1,
#          'beloved': 1,
#          'doctrine': 1,
#          'extraordinary': 1,
#          'dies': 1,
#          'reprobation': 1,
#          'confirm': 1,
#          'belief': 1,
#          'reason': 1,
#          'end': 1,
#          'creation': 1,
#          'increase': 1,
#          'multiply': 1,
#          'properly': 1,
#          'employed': 1,
#          'works': 1,
#          'calling': 1,
#          'bringing': 1,
#          'forth': 1,
#          'taking': 1,
#          'care': 1,
#          'virtues': 1,
#          'expects': 1,
#          'indeed': 1,
#          'life': 1,
#          'shuts': 1,
#          'public': 1,
#          'commerce': 1,
#          'does': 1,
#          'permit': 1,
#          'vulgar': 1,
#          'mistake': 1,
#          'say': 1,
#          'elevated': 1,
#          'kind': 1,
#          'admitted': 1,
#          'paradise': 1,
#          'appointed': 1,
#          'entertained': 1,
#          'celestial': 1,
#          'happiness': 1,
#          'inferior': 1,
#          'order': 1,
#          'eternal': 1,
#          'bliss': 1,
#          'many': 1,
#          'superstitious': 1,
#          'remain': 1,
#          'widows': 1,
#          'ten': 1,
#          'days': 1,
#          'fear': 1,
#          'reprobate': 1,
#          'useless': 1,
#          'creature': 1,
#          'like': 1,
#          'liberty': 1,
#          'slaves': 1,
#          'content': 1,
#          'marrying': 1,
#          'afraid': 1,
#          'theology': 1,
#          'acceptable': 1,
#          'vow': 1,
#          'perpetual': 1,
#          'virginity': 1,
#          'divinity': 1,
#          'rational': 1,
#          'leave': 1,
#          'determine': 1,
#          'already': 1,
#          'progress': 1,
#          'collection': 1,
#          'professed': 1,
#          'ready': 1,
#          'serve': 1,
#          'desires': 1,
#          'cannot': 1,
#          'stare': 1,
#          'enquire': 1,
#          'if': 1,
#          'permitted': 1,
#          'seek': 1,
#          'till': 1,
#          'grown': 1,
#          'antiquity': 1,
#          'got': 1,
#          'ones': 1,
#          'macedonian': 1,
#          'kings': 1,
#          'particularly': 1,
#          'perseus': 1,
#          'lively': 1,
#          'ill': 1,
#          'qualities': 1,
#          'prophyry': 1,
#          'finely': 1,
#          'cut': 1,
#          'sculpture': 1,
#          'represents': 1,
#          'guessed': 1,
#          'learned': 1,
#          'return': 1,
#          'suppose': 1,
#          'these': 1,
#          'thing': 1,
#          'trade': 1,
#          'sell': 1,
#          'correspondents': 1,
#          'aleppo': 1,
#          'cairo': 1,
#          'arabia': 1,
#          'palestine': 1,
#          'send': 1,
#          'often': 1,
#          'heaps': 1,
#          'fit': 1,
#          'melt': 1,
#          'pans': 1,
#          'kettles': 1,
#          'get': 1,
#          'knowing': 1,
#          'pretend': 1,
#          'skill': 1,
#          'generally': 1,
#          'image': 1,
#          'cities': 1,
#          'shewing': 1,
#          'figure': 1,
#          'pallas': 1,
#          'victory': 1,
#          'reverse': 1,
#          'assured': 1,
#          'holding': 1,
#          'crucifix': 1,
#          'offered': 1,
#          'socrates': 1,
#          'sardonyx': 1,
#          'enhance': 1,
#          'value': 1,
#          'title': 1,
#          'augustine': 1,
#          'bespoke': 1,
#          'safe': 1,
#          'hands': 1,
#          'notwithstanding': 1,
#          'misfortune': 1,
#          'befel': 1,
#          'king': 1,
#          'sweden': 1,
#          'turks': 1,
#          'took': 1,
#          'heads': 1,
#          'project': 1,
#          'depending': 1,
#          'fancied': 1,
#          'knows': 1,
#          'empire': 1,
#          'mystically': 1,
#          'depended': 1,
#          'conversation': 1,
#          'old': 1,
#          'prophecies': 1,
#          'remembered': 1,
#          'committed': 1,
#          'prisoner': 1,
#          'seven': 1,
#          'towers': 1,
#          'remained': 1,
#          'under': 1,
#          'close': 1,
#          'confinement': 1,
#          'since': 1,
#          'dare': 1,
#          'try': 1,
#          'interest': 1,
#          'release': 1,
#          'mine': 1,
#          'examination': 1,
#          'shall': 1,
#          'hear': 1,
#          'am': 1,
#          'sir': 1,
#          "your's": 1})

# %% [markdown]
# Another neat piece of code is .most_common()
#
# Gotta love the Counter tools

# %%
unique_word_counts.most_common(10)
# Out:
# [('the', 100),
#  ('of', 88),
#  ('a', 61),
#  ('to', 49),
#  ('i', 45),
#  ('and', 40),
#  ('in', 30),
#  ('is', 23),
#  ('it', 22),
#  ('that', 21)]

# %% [markdown]
# <div style="background: rgba(167, 139, 250, 0.12); border-radius: 6px; padding: 0.6em 1em; margin: 1.5em 0; font-weight: 500;">
#  Does something stand out to you about the top 10 most frequent words?
# </div>

# %% [markdown]
# ## Step 4: Stopwords

# %% [markdown]
# [Stop words](https://en.wikipedia.org/wiki/Stop_words) are the most common words in a language, and may or may not add information about the content of the analysis.

# %% [markdown]
# There are a lot of ways to handle stopwords in a corpus. If your (English language) texts have over a million or so words, you can simply get rid of top 100-200 most frequent words, depending on the specifics of your corpus.
#
# Otherwise, another very common method is to use lists of stopwords.
#
# Similar to what we did with punctuation, we will use an external library to acquire a list of stopword, specificially designed for English

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/mervetekgurler/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# [NLTK](https://www.nltk.org/) stands for Natural Language Toolkit and is a Python library that provides tools for working with human language data (over 50 languages!), such as tokenizing text, removing stopwords, and analyzing word frequencies.
#
# We will talk more about NLTK! For now, let's just take a quick look at their stopwords

# %%
stopwords_en = stopwords.words("english")
print(stopwords_en)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]

# %%
words_no_stop = []

for word in words:
    if word not in stopwords.words('english'):
        words_no_stop.append(word)

print(words_no_stop)
# Out:
# ['advantage', 'fine', 'weather', 'journey', 'summer', 'beauty', 'enjoyed', 'pleasure', 'fine', 'prospects', 'meadows', 'full', 'sorts', 'garden', 'flowers', 'sweet', 'herbs', 'berlin', 'perfumed', 'air', 'pressed', 'grand', 'signior', 'furnished', 'us', 'thirty', 'covered', 'waggons', 'baggage', 'five', 'coaches', 'country', 'women', 'found', 'road', 'full', 'great', 'spahis', 'equipages', 'coming', 'asia', 'war', 'always', 'travel', 'tents', 'chose', 'ly', 'houses', 'way', 'trouble', 'names', 'villages', 'passed', 'nothing', 'remarkable', 'ciorlei', 'conac', 'little', 'seraglio', 'built', 'use', 'grand', 'signior', 'goes', 'road', 'curiosity', 'view', 'apartments', 'destined', 'ladies', 'court', 'midst', 'thick', 'grove', 'trees', 'made', 'fresh', 'fountains', 'surprised', 'see', 'walls', 'almost', 'covered', 'little', 'distiches', 'turkish', 'verse', 'wrote', 'pencils', 'made', 'interpreter', 'explain', 'found', 'several', 'well', 'turned', 'though', 'easily', 'believed', 'lost', 'much', 'beauty', 'translation', 'one', 'literally', 'thus', 'english', 'come', 'world', 'lodge', 'depart', 'never', 'goes', "that's", 'lodged', 'within', 'heart', 'rest', 'journey', 'fine', 'painted', 'meadows', 'side', 'sea', 'marmora', 'ancient', 'propontis', 'lay', 'next', 'night', 'selivrea', 'anciently', 'noble', 'town', 'good', 'sea-port', 'neatly', 'built', 'enough', 'bridge', 'thirty-two', 'arches', 'famous', 'ancient', 'greek', 'church', 'given', 'one', 'coaches', 'greek', 'lady', 'desired', 'conveniency', 'travelling', 'designed', 'pay', 'devotions', 'glad', 'opportunity', 'going', 'found', 'ill-built', 'edifice', 'set', 'sort', 'ornaments', 'less', 'rich', 'roman-catholic', 'churches', 'shewed', "saint's", 'body', 'threw', 'piece', 'money', 'picture', 'virgin', 'mary', 'drawn', 'hand', 'st', 'luke', 'little', 'credit', 'painting', 'however', 'finest', 'madona', 'sic', 'italy', 'famous', 'miracles', 'greeks', 'monstrous', 'taste', 'pictures', 'finery', 'always', 'drawn', 'upon', 'gold', 'ground', 'may', 'imagine', 'good', 'air', 'notion', 'either', 'shade', 'proportion', 'bishop', 'officiated', 'purple', 'robe', 'sent', 'candle', 'almost', 'big', 'present', 'lodging', 'lay', 'night', 'town', 'called', 'bujuk', 'cekmege', 'great', 'bridge', 'night', 'following', 'kujuk', 'cekmege', 'little', 'bridge', 'pleasant', 'lodging', 'formerly', 'monastery', 'dervises', 'large', 'court', 'encompassed', 'marble', 'cloisters', 'good', 'fountain', 'middle', 'prospect', 'place', 'gardens', 'round', 'agreeable', 'seen', 'shews', 'monks', 'religions', 'know', 'chuse', 'retirements', 'tis', 'belonging', 'hogia', 'schoolmaster', 'teaches', 'boys', 'asked', 'shew', 'apartment', 'surprised', 'see', 'point', 'tall', 'cypress', 'tree', 'garden', 'top', 'place', 'bed', 'little', 'lower', 'one', 'wife', 'two', 'children', 'slept', 'every', 'night', 'much', 'diverted', 'fancy', 'resolved', 'examine', 'nest', 'nearer', 'going', 'fifty', 'steps', 'found', 'still', 'fifty', 'go', 'must', 'climb', 'branch', 'branch', 'hazard', 'neck', 'thought', 'therefore', 'best', 'way', 'come', 'arrived', 'next', 'day', 'constantinople', 'yet', 'tell', 'little', 'time', 'taken', 'receiving', 'visits', 'least', 'good', 'entertainment', 'eyes', 'young', 'women', 'beauties', 'beauty', 'highly', 'improved', 'high', 'taste', 'dress', 'palace', 'pera', 'suburb', 'constantinople', 'westminster', 'suburb', 'london', 'ambassadors', 'lodged', 'near', 'one', 'part', 'house', 'shews', 'us', 'port', 'city', 'seraglio', 'distant', 'hills', 'asia', 'perhaps', 'together', 'beautiful', 'prospect', 'world', 'certain', 'french', 'author', 'says', 'constantinople', 'twice', 'big', 'paris', 'mr', 'w----y', 'unwilling', 'tis', 'bigger', 'london', 'though', 'confess', 'appears', 'believe', 'populous', 'burying', 'fields', 'certainly', 'much', 'larger', 'whole', 'city', 'tis', 'surprising', 'vast', 'deal', 'land', 'lost', 'way', 'turkey', 'sometimes', 'seen', 'burying', 'places', 'several', 'miles', 'belo ...

# %%
words_no_stop_counts = Counter(words_no_stop)
words_no_stop_counts.most_common(10)
# Out:
# [('one', 9),
#  ('little', 7),
#  ('great', 6),
#  ('tis', 6),
#  ('fine', 5),
#  ('night', 5),
#  ('good', 5),
#  ('greek', 5),
#  ('upon', 5),
#  ('women', 4)]

# %% [markdown]
# ### 🥊 Challenge 9: How many unique words do we have after stopword removal?

# %%
# remember how we can nest functions?

print(len(set(words_no_stop)))
# Out:
# 589

# %% [markdown]
# From 681 to 589! We removed about 13.5% of our unique words

# %% [markdown]
# ## Step 5: Sentences

# %% [markdown]
# Another common way to approach text analysis is to start with sentences. If tokenization assumes that the smallest unit of analysis is a word, splitting text into sentences, assumes that the smallest unit of analysis is a sentence.
#
# Splitting into sentences is super useful for many syntax analysis. Sentences retain a lot more context than individual words. Let's look at this sentence from Letter 35
#
# `The burying fields about it are certainly much larger than the whole city.`
#
# `The burying fields` here refers to cemeteries, whereas in another context `burying` could be a verb. When we split the whole text into words, we inevitably flatten some of the meaning in these texts.

# %% [markdown]
# Luckily, there is another NLTK module for sentence tokenization

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/mervetekgurler/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/mervetekgurler/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
sentences = sent_tokenize(letter_35)

# %%
# Here is another way to do a fancy print statement

print(f"Number of sentences in letter 35: {len(sentences)}")
# Out:
# Number of sentences in letter 35: 68

# %%
# And another wat

counter = 1
for sentence in sentences:
    print(counter) 
    print(sentence)
    counter += 1
# Out:
# 1
# I HAVE had the advantage of very fine weather, all my journey; and as
# the summer is now in its beauty, I enjoyed the pleasure of fine
# prospects; and the meadows being full of all sorts of garden flowers,
# and sweet herbs, my berlin perfumed the air as it pressed them.
# 2
# The
# grand signior furnished us with thirty covered waggons for our
# baggage, and five coaches of the country for my women.
# 3
# We found the
# road full of the great spahis and their equipages coming out of Asia
# to the war.
# 4
# They always travel with tents; but I chose to ly in
# houses all the way.
# 5
# I will not trouble you with the names of the
# villages we passed, in which there was nothing remarkable, but at
# Ciorlei, where there was a _conac_, or little seraglio, built for the
# use of the grand signior, when he goes this road.
# 6
# I had the
# curiosity to view all the apartments destined for the ladies of his
# court.
# 7
# They were in the midst of a thick grove of trees, made fresh
# by fountains; but I was most surprised to see the walls almost
# covered with little distiches of Turkish verse, wrote with pencils.
# 8
# I made my interpreter explain them to me, and I found several of them
# very well turned; though I easily believed him, that they had lost
# much of their beauty in the translation.
# 9
# One was literally thus in
# English:
#
#          _We come into this world; we lodge, and we depart;
#           He never goes, that's lodged within my heart._
#
# THE rest of our journey was through fine painted meadows, by the side
# of the sea of Marmora, the ancient Propontis.
# 10
# We lay the next night
# at Selivrea, anciently a noble town.
# 11
# It is now a good sea-port, and
# neatly built enough, and has a bridge of thirty-two arches.
# 12
# Here is
# a famous ancient Greek church.
# 13
# I had given one of my coaches to a
# Greek lady, who desired the conveniency of travelling with me; she
# designed to pay her devotions, and I was glad of the opportunity of
# going with her.
# 14
# I found it an ill-built edifice, set out with the
# same sort of ornaments, but less rich, as the Roman-catholic
# churches.
# 15
# They shewed me a saint's body, where I threw a piece of
# money; and a picture of the virgin Mary, drawn by the hand of St
# Luke, very little to the credit of his painting; but, however, the
# finest Madona (sic) of Italy, is not more famous for her miracles.
# 16
# The Greeks have a monstrous taste in their pictures, which, for more
# finery, are always drawn upon a gold ground.
# 17
# You may imagine what a
# good air this has; but they have no notion, either of shade or
# proportion.
# 18
# They have a bishop here, who officiated in his purple
# robe, and sent me a candle almost as big as myself for a present,
# when I was at my lodging.
# 19
# We lay that night at a town called Bujuk
# Cekmege, or Great Bridge; and the night following, at Kujuk Cekmege,
# or Little Bridge; in a very pleasant lodging, formerly a monastery of
# dervises; having before it a large court, encompassed with marble
# cloisters, with a good fountain in the middle.
# 20
# The prospect from
# this place, and the gardens round it, is the most agreeable I have
# seen; and shews, that monks of all religions know how to chuse their
# retirements.
# 21
# 'Tis now belonging to a _hogia_ or schoolmaster, who
# teaches boys here.
# 22
# I asked him to shew me his own apartment, and was
# surprised to see him point to a tall cypress tree in the garden, on
# the top of which was a place for a bed for himself, and a little
# lower, one for his wife and two children, who slept there every
# night.
# 23
# I was so much diverted with the fancy, I resolved to examine
# his nest nearer; but after going up fifty steps, I found I had still
# fifty to go up, and then I must climb from branch to branch, with
# some hazard of my neck.
# 24
# I thought it therefore the best way to come
# down again.
# 25
# WE arrived the next day at Constantinople; but I can yet tell you
# very little of it, all my time having been taken up with receiving
# visits, which are, at least, a very good entertainment to the eyes,
# the young women being all beauties, and their beauty highly improved
# by the high taste of their dress.
# 26
# Our palace is in Pera, which is no
# more a suburb of Constantinople, than Westminster is a suburb to
# London.
# 27
# All the ambassadors are lodged very near each other.
# 28
# One
# part of our house shews us the port, the city, and the seraglio, and
# the distant hills of Asia; perhaps, all together, the most beautiful
# prospect in the world.
# 29
# A CERTAIN French author says, Constantinople is twice as big as
# Paris.
# 30
# Mr W----y is unwilling to own 'tis bigger than London, though
# I confess it appears to me to be so; but I don't believe it is so
# populous.
# 31
# The burying fields about it are certainly much larger than
# the whole city.
# 32
# 'Tis surprising what a vast deal of land is lost
# this way in Turkey.
# 33
# Sometimes I have seen burying places of several
# miles, belonging to very inconsiderable villages, which were formerly
# great towns, and retain no other mark of their ancient grandeur, than
# this dismal one.
# 34
# On no occasion do they ever remove a stone that
# serves for a monument.
# 35
# Some of them are costly enough, being of very
# fine marble.
# 36
# They set up a pillar, with a carved turbant on the top
# of it, to the memory of a man; and as the turbants, by their
# different shapes, shew the quality or profession, 'tis in a manner
# putting up the arms of the deceased; besides, the pillar commonly
# bears an inscription in gold letters.
# 37
# The ladies have a simple
# pillar without other ornament, except those that die unmarried, who
# have a rose on the top of their monument.
# 38
# The sepulchres of
# particular families are railed in, and planted round with trees.
# 39
# Those of the sultans, and some great men, have lamps constantly
# burning in them.
# 40
# WHEN I spoke of their religion, I forgot to mention two
# particularities, one of which I have read of, but it seemed so odd to
# me, I could not believe it; yet 'tis certainly true; that when a man
# has divorced his wife, in the most solemn manner, he can take her
# again, upon no other terms, than permitting another man to pass a
# night with her; and there are some examples of those who have
# submitted to this law, rather than not have back their beloved.
# 41
# The
# other point of doctrine is very extraordinary.
# 42
# Any woman that dies
# unmarried is looked upon to die in a state of reprobation.
# 43
# To
# confirm this belief, they reason, that the end of the creation of
# woman is to increase and multiply; and that she is only properly
# employed in the works of her calling, when she is bringing forth
# children, or taking care of them, which are all the virtues that God
# expects from her.
# 44
# And indeed, their way of life, which shuts them
# out of all public commerce, does not permit them any other.
# 45
# Our
# vulgar notion, that they don't own women to have any souls, is a
# mistake.
# 46
# 'Tis true, they say, they are not of so elevated a kind,
# and therefore must not hope to be admitted into the paradise
# appointed for the men, who are to be entertained by celestial
# beauties.
# 47
# But there is a place of happiness destined for souls of
# the inferior order, where all good women are to be in eternal bliss.
# 48
# Many of them are very superstitious, and will not remain widows ten
# days, for fear of dying in the reprobate state of an useless
# creature.
# 49
# But those that like their liberty, and are not slaves to
# their religion, content themselves with marrying when they are afraid
# of dying.
# 50
# This is a piece of theology, very different from that
# which teaches nothing to be more acceptable to God than a vow of
# perpetual virginity: which divinity is most rational, I leave you to
# determine.
# 51
# I HAVE already made some progress in a collection of Greek medals.
# 52
# Here are several professed antiquaries, who are ready to serve any
# body that desires them.
# 53
# But you cannot imagine how they stare in my
# face, when I enquire about them, as if no body was permitted to seek
# after medals, till they were grown a piece of antiquity themselves.
# 54
# I have got some very valuable ones of the Macedonian kings,
# particularly one of Perseus, so lively, I fancy I can see all his ill
# qualities in his face.
# 55
# I have a prophyry (sic) head finely cut, of
# the true Greek sculpture; but who it represents, is to be guessed at
# by the learned when I return.
# 56
# For you are not to suppose these
# antiquaries (who are all Greeks) know any thing.
# 57
# Their trade is only
# to sell; they have correspondents at Aleppo, Grand Cairo, in Arabia
# and Palestine, who send them all they can find, and very often great
# heaps, that are only fit to melt into pans and kettles.
# 58
# They get the
# best price they can for them, without knowing those that are valuable
# from those that are not.
# 59
# Those that pretend to skill, generally find
# out the image of some saint in the medals of the Greek cities.
# 60
# One
# of them, shewing me the figure of a Pallas, with a victory in her
# hand on a reverse, assured me, it was the Virgin, holding a crucifix.
# 61
# The same man offered me the head of a Socrates, on a sardonyx; and,
# to enhance the value, gave him the title of saint Augustine.
# 62
# I have
# bespoke a mummy, which I hope will come safe to my hands,
# notwithstanding the misfortune that befel (sic) a very fine one,
# designed for the king of Sweden.
# 63
# He gave a great price for it, and
# the Turks took it into their heads, that he must have some
# considerable project depending upon it.
# 64
# They fancied it the body of,
# God knows who; and that the state of their empire mystically depended
# on the conversation of it.
# 65
# Some old prophecies were remembered upon
# this occasion, and the mummy committed prisoner to the Seven Towers,
# where it has remained under close confinement ever since, I dare not
# try my interest in so considerable a point, as the release of it; but
# I hope mine will pass without examination.
# 66
# I can  tell you nothing
# more at present of this famous city.
# 67
# When I have looked a little
# about me, you shall hear from me again.
# 68
# I am, Sir,   Your's, &c. &c.

# %% [markdown]
# Printing it this way, we can see that the sentences have some line break issues. This is normal and doesn't really mean much, but let's clean it either way.

# %%
letter_35 = letter_35.replace('\n', ' ')

# %%
sentences = sent_tokenize(letter_35)

# %%
counter = 1
for sentence in sentences:
    print(counter) 
    print(sentence)
    counter += 1
# Out:
# 1
# I HAVE had the advantage of very fine weather, all my journey; and as the summer is now in its beauty, I enjoyed the pleasure of fine prospects; and the meadows being full of all sorts of garden flowers, and sweet herbs, my berlin perfumed the air as it pressed them.
# 2
# The grand signior furnished us with thirty covered waggons for our baggage, and five coaches of the country for my women.
# 3
# We found the road full of the great spahis and their equipages coming out of Asia to the war.
# 4
# They always travel with tents; but I chose to ly in houses all the way.
# 5
# I will not trouble you with the names of the villages we passed, in which there was nothing remarkable, but at Ciorlei, where there was a _conac_, or little seraglio, built for the use of the grand signior, when he goes this road.
# 6
# I had the curiosity to view all the apartments destined for the ladies of his court.
# 7
# They were in the midst of a thick grove of trees, made fresh by fountains; but I was most surprised to see the walls almost covered with little distiches of Turkish verse, wrote with pencils.
# 8
# I made my interpreter explain them to me, and I found several of them very well turned; though I easily believed him, that they had lost much of their beauty in the translation.
# 9
# One was literally thus in English:           _We come into this world; we lodge, and we depart;           He never goes, that's lodged within my heart._  THE rest of our journey was through fine painted meadows, by the side of the sea of Marmora, the ancient Propontis.
# 10
# We lay the next night at Selivrea, anciently a noble town.
# 11
# It is now a good sea-port, and neatly built enough, and has a bridge of thirty-two arches.
# 12
# Here is a famous ancient Greek church.
# 13
# I had given one of my coaches to a Greek lady, who desired the conveniency of travelling with me; she designed to pay her devotions, and I was glad of the opportunity of going with her.
# 14
# I found it an ill-built edifice, set out with the same sort of ornaments, but less rich, as the Roman-catholic churches.
# 15
# They shewed me a saint's body, where I threw a piece of money; and a picture of the virgin Mary, drawn by the hand of St Luke, very little to the credit of his painting; but, however, the finest Madona (sic) of Italy, is not more famous for her miracles.
# 16
# The Greeks have a monstrous taste in their pictures, which, for more finery, are always drawn upon a gold ground.
# 17
# You may imagine what a good air this has; but they have no notion, either of shade or proportion.
# 18
# They have a bishop here, who officiated in his purple robe, and sent me a candle almost as big as myself for a present, when I was at my lodging.
# 19
# We lay that night at a town called Bujuk Cekmege, or Great Bridge; and the night following, at Kujuk Cekmege, or Little Bridge; in a very pleasant lodging, formerly a monastery of dervises; having before it a large court, encompassed with marble cloisters, with a good fountain in the middle.
# 20
# The prospect from this place, and the gardens round it, is the most agreeable I have seen; and shews, that monks of all religions know how to chuse their retirements.
# 21
# 'Tis now belonging to a _hogia_ or schoolmaster, who teaches boys here.
# 22
# I asked him to shew me his own apartment, and was surprised to see him point to a tall cypress tree in the garden, on the top of which was a place for a bed for himself, and a little lower, one for his wife and two children, who slept there every night.
# 23
# I was so much diverted with the fancy, I resolved to examine his nest nearer; but after going up fifty steps, I found I had still fifty to go up, and then I must climb from branch to branch, with some hazard of my neck.
# 24
# I thought it therefore the best way to come down again.
# 25
# WE arrived the next day at Constantinople; but I can yet tell you very little of it, all my time having been taken up with receiving visits, which are, at least, a very good entertainment to the eyes, the young women being all beauties, and their beauty highly improved by the high taste of their dress.
# 26
# Our palace is in Pera, which is no more a suburb of Constantinople, than Westminster is a suburb to London.
# 27
# All the ambassadors are lodged very near each other.
# 28
# One part of our house shews us the port, the city, and the seraglio, and the distant hills of Asia; perhaps, all together, the most beautiful prospect in the world.
# 29
# A CERTAIN French author says, Constantinople is twice as big as Paris.
# 30
# Mr W----y is unwilling to own 'tis bigger than London, though I confess it appears to me to be so; but I don't believe it is so populous.
# 31
# The burying fields about it are certainly much larger than the whole city.
# 32
# 'Tis surprising what a vast deal of land is lost this way in Turkey.
# 33
# Sometimes I have seen burying places of several miles, belonging to very inconsiderable villages, which were formerly great towns, and retain no other mark of their ancient grandeur, than this dismal one.
# 34
# On no occasion do they ever remove a stone that serves for a monument.
# 35
# Some of them are costly enough, being of very fine marble.
# 36
# They set up a pillar, with a carved turbant on the top of it, to the memory of a man; and as the turbants, by their different shapes, shew the quality or profession, 'tis in a manner putting up the arms of the deceased; besides, the pillar commonly bears an inscription in gold letters.
# 37
# The ladies have a simple pillar without other ornament, except those that die unmarried, who have a rose on the top of their monument.
# 38
# The sepulchres of particular families are railed in, and planted round with trees.
# 39
# Those of the sultans, and some great men, have lamps constantly burning in them.
# 40
# WHEN I spoke of their religion, I forgot to mention two particularities, one of which I have read of, but it seemed so odd to me, I could not believe it; yet 'tis certainly true; that when a man has divorced his wife, in the most solemn manner, he can take her again, upon no other terms, than permitting another man to pass a night with her; and there are some examples of those who have submitted to this law, rather than not have back their beloved.
# 41
# The other point of doctrine is very extraordinary.
# 42
# Any woman that dies unmarried is looked upon to die in a state of reprobation.
# 43
# To confirm this belief, they reason, that the end of the creation of woman is to increase and multiply; and that she is only properly employed in the works of her calling, when she is bringing forth children, or taking care of them, which are all the virtues that God expects from her.
# 44
# And indeed, their way of life, which shuts them out of all public commerce, does not permit them any other.
# 45
# Our vulgar notion, that they don't own women to have any souls, is a mistake.
# 46
# 'Tis true, they say, they are not of so elevated a kind, and therefore must not hope to be admitted into the paradise appointed for the men, who are to be entertained by celestial beauties.
# 47
# But there is a place of happiness destined for souls of the inferior order, where all good women are to be in eternal bliss.
# 48
# Many of them are very superstitious, and will not remain widows ten days, for fear of dying in the reprobate state of an useless creature.
# 49
# But those that like their liberty, and are not slaves to their religion, content themselves with marrying when they are afraid of dying.
# 50
# This is a piece of theology, very different from that which teaches nothing to be more acceptable to God than a vow of perpetual virginity: which divinity is most rational, I leave you to determine.
# 51
# I HAVE already made some progress in a collection of Greek medals.
# 52
# Here are several professed antiquaries, who are ready to serve any body that desires them.
# 53
# But you cannot imagine how they stare in my face, when I enquire about them, as if no body was permitted to seek after medals, till they were grown a piece of antiquity themselves.
# 54
# I have got some very valuable ones of the Macedonian kings, particularly one of Perseus, so lively, I fancy I can see all his ill qualities in his face.
# 55
# I have a prophyry (sic) head finely cut, of the true Greek sculpture; but who it represents, is to be guessed at by the learned when I return.
# 56
# For you are not to suppose these antiquaries (who are all Greeks) know any thing.
# 57
# Their trade is only to sell; they have correspondents at Aleppo, Grand Cairo, in Arabia and Palestine, who send them all they can find, and very often great heaps, that are only fit to melt into pans and kettles.
# 58
# They get the best price they can for them, without knowing those that are valuable from those that are not.
# 59
# Those that pretend to skill, generally find out the image of some saint in the medals of the Greek cities.
# 60
# One of them, shewing me the figure of a Pallas, with a victory in her hand on a reverse, assured me, it was the Virgin, holding a crucifix.
# 61
# The same man offered me the head of a Socrates, on a sardonyx; and, to enhance the value, gave him the title of saint Augustine.
# 62
# I have bespoke a mummy, which I hope will come safe to my hands, notwithstanding the misfortune that befel (sic) a very fine one, designed for the king of Sweden.
# 63
# He gave a great price for it, and the Turks took it into their heads, that he must have some considerable project depending upon it.
# 64
# They fancied it the body of, God knows who; and that the state of their empire mystically depended on the conversation of it.
# 65
# Some old prophecies were remembered upon this occasion, and the mummy committed prisoner to the Seven Towers, where it has remained under close confinement ever since, I dare not try my interest in so considerable a point, as the release of it; but I hope mine will pass without examination.
# 66
# I can  tell you nothing more at present of this famous city.
# 67
# When I have looked a little about me, you shall hear from me again.
# 68
# I am, Sir,   Your's, &c. &c.

# %%
# When we split it sentence by sentence, we can see that the sentences have some line break issues
# Sometimes analyzing the text can reveal formatting issues that need to be addressed, 
# especially when dealing with historical texts or texts extracted from formats like ePub.

# Let's fix the line breaks in the actual letter

letter_35_test = letter_35.replace('\n', ' ')

letter_35_sentences_test = sent_tokenize(letter_35_test)

print(f"Number of sentences in letter 35: {len(letter_35_sentences_test)}")

counter = 1
for sentence in letter_35_sentences_test:
    print(counter) 
    print(sentence)
    counter += 1
# Out:
# Number of sentences in letter 35: 68
# 1
# I HAVE had the advantage of very fine weather, all my journey; and as the summer is now in its beauty, I enjoyed the pleasure of fine prospects; and the meadows being full of all sorts of garden flowers, and sweet herbs, my berlin perfumed the air as it pressed them.
# 2
# The grand signior furnished us with thirty covered waggons for our baggage, and five coaches of the country for my women.
# 3
# We found the road full of the great spahis and their equipages coming out of Asia to the war.
# 4
# They always travel with tents; but I chose to ly in houses all the way.
# 5
# I will not trouble you with the names of the villages we passed, in which there was nothing remarkable, but at Ciorlei, where there was a _conac_, or little seraglio, built for the use of the grand signior, when he goes this road.
# 6
# I had the curiosity to view all the apartments destined for the ladies of his court.
# 7
# They were in the midst of a thick grove of trees, made fresh by fountains; but I was most surprised to see the walls almost covered with little distiches of Turkish verse, wrote with pencils.
# 8
# I made my interpreter explain them to me, and I found several of them very well turned; though I easily believed him, that they had lost much of their beauty in the translation.
# 9
# One was literally thus in English:           _We come into this world; we lodge, and we depart;           He never goes, that's lodged within my heart._  THE rest of our journey was through fine painted meadows, by the side of the sea of Marmora, the ancient Propontis.
# 10
# We lay the next night at Selivrea, anciently a noble town.
# 11
# It is now a good sea-port, and neatly built enough, and has a bridge of thirty-two arches.
# 12
# Here is a famous ancient Greek church.
# 13
# I had given one of my coaches to a Greek lady, who desired the conveniency of travelling with me; she designed to pay her devotions, and I was glad of the opportunity of going with her.
# 14
# I found it an ill-built edifice, set out with the same sort of ornaments, but less rich, as the Roman-catholic churches.
# 15
# They shewed me a saint's body, where I threw a piece of money; and a picture of the virgin Mary, drawn by the hand of St Luke, very little to the credit of his painting; but, however, the finest Madona (sic) of Italy, is not more famous for her miracles.
# 16
# The Greeks have a monstrous taste in their pictures, which, for more finery, are always drawn upon a gold ground.
# 17
# You may imagine what a good air this has; but they have no notion, either of shade or proportion.
# 18
# They have a bishop here, who officiated in his purple robe, and sent me a candle almost as big as myself for a present, when I was at my lodging.
# 19
# We lay that night at a town called Bujuk Cekmege, or Great Bridge; and the night following, at Kujuk Cekmege, or Little Bridge; in a very pleasant lodging, formerly a monastery of dervises; having before it a large court, encompassed with marble cloisters, with a good fountain in the middle.
# 20
# The prospect from this place, and the gardens round it, is the most agreeable I have seen; and shews, that monks of all religions know how to chuse their retirements.
# 21
# 'Tis now belonging to a _hogia_ or schoolmaster, who teaches boys here.
# 22
# I asked him to shew me his own apartment, and was surprised to see him point to a tall cypress tree in the garden, on the top of which was a place for a bed for himself, and a little lower, one for his wife and two children, who slept there every night.
# 23
# I was so much diverted with the fancy, I resolved to examine his nest nearer; but after going up fifty steps, I found I had still fifty to go up, and then I must climb from branch to branch, with some hazard of my neck.
# 24
# I thought it therefore the best way to come down again.
# 25
# WE arrived the next day at Constantinople; but I can yet tell you very little of it, all my time having been taken up with receiving visits, which are, at least, a very good entertainment to the eyes, the young women being all beauties, and their beauty highly improved by the high taste of their dress.
# 26
# Our palace is in Pera, which is no more a suburb of Constantinople, than Westminster is a suburb to London.
# 27
# All the ambassadors are lodged very near each other.
# 28
# One part of our house shews us the port, the city, and the seraglio, and the distant hills of Asia; perhaps, all together, the most beautiful prospect in the world.
# 29
# A CERTAIN French author says, Constantinople is twice as big as Paris.
# 30
# Mr W----y is unwilling to own 'tis bigger than London, though I confess it appears to me to be so; but I don't believe it is so populous.
# 31
# The burying fields about it are certainly much larger than the whole city.
# 32
# 'Tis surprising what a vast deal of land is lost this way in Turkey.
# 33
# Sometimes I have seen burying places of several miles, belonging to very inconsiderable villages, which were formerly great towns, and retain no other mark of their ancient grandeur, than this dismal one.
# 34
# On no occasion do they ever remove a stone that serves for a monument.
# 35
# Some of them are costly enough, being of very fine marble.
# 36
# They set up a pillar, with a carved turbant on the top of it, to the memory of a man; and as the turbants, by their different shapes, shew the quality or profession, 'tis in a manner putting up the arms of the deceased; besides, the pillar commonly bears an inscription in gold letters.
# 37
# The ladies have a simple pillar without other ornament, except those that die unmarried, who have a rose on the top of their monument.
# 38
# The sepulchres of particular families are railed in, and planted round with trees.
# 39
# Those of the sultans, and some great men, have lamps constantly burning in them.
# 40
# WHEN I spoke of their religion, I forgot to mention two particularities, one of which I have read of, but it seemed so odd to me, I could not believe it; yet 'tis certainly true; that when a man has divorced his wife, in the most solemn manner, he can take her again, upon no other terms, than permitting another man to pass a night with her; and there are some examples of those who have submitted to this law, rather than not have back their beloved.
# 41
# The other point of doctrine is very extraordinary.
# 42
# Any woman that dies unmarried is looked upon to die in a state of reprobation.
# 43
# To confirm this belief, they reason, that the end of the creation of woman is to increase and multiply; and that she is only properly employed in the works of her calling, when she is bringing forth children, or taking care of them, which are all the virtues that God expects from her.
# 44
# And indeed, their way of life, which shuts them out of all public commerce, does not permit them any other.
# 45
# Our vulgar notion, that they don't own women to have any souls, is a mistake.
# 46
# 'Tis true, they say, they are not of so elevated a kind, and therefore must not hope to be admitted into the paradise appointed for the men, who are to be entertained by celestial beauties.
# 47
# But there is a place of happiness destined for souls of the inferior order, where all good women are to be in eternal bliss.
# 48
# Many of them are very superstitious, and will not remain widows ten days, for fear of dying in the reprobate state of an useless creature.
# 49
# But those that like their liberty, and are not slaves to their religion, content themselves with marrying when they are afraid of dying.
# 50
# This is a piece of theology, very different from that which teaches nothing to be more acceptable to God than a vow of perpetual virginity: which divinity is most rational, I leave you to determine.
# 51
# I HAVE already made some progress in a collection of Greek medals.
# 52
# Here are several professed antiquaries, who are ready to serve any body that desires them.
# 53
# But you cannot imagine how they stare in my face, when I enquire about them, as if no body was permitted to seek after medals, till they were grown a piece of antiquity themselves.
# 54
# I have got some very valuable ones of the Macedonian kings, particularly one of Perseus, so lively, I fancy I can see all his ill qualities in his face.
# 55
# I have a prophyry (sic) head finely cut, of the true Greek sculpture; but who it represents, is to be guessed at by the learned when I return.
# 56
# For you are not to suppose these antiquaries (who are all Greeks) know any thing.
# 57
# Their trade is only to sell; they have correspondents at Aleppo, Grand Cairo, in Arabia and Palestine, who send them all they can find, and very often great heaps, that are only fit to melt into pans and kettles.
# 58
# They get the best price they can for them, without knowing those that are valuable from those that are not.
# 59
# Those that pretend to skill, generally find out the image of some saint in the medals of the Greek cities.
# 60
# One of them, shewing me the figure of a Pallas, with a victory in her hand on a reverse, assured me, it was the Virgin, holding a crucifix.
# 61
# The same man offered me the head of a Socrates, on a sardonyx; and, to enhance the value, gave him the title of saint Augustine.
# 62
# I have bespoke a mummy, which I hope will come safe to my hands, notwithstanding the misfortune that befel (sic) a very fine one, designed for the king of Sweden.
# 63
# He gave a great price for it, and the Turks took it into their heads, that he must have some considerable project depending upon it.
# 64
# They fancied it the body of, God knows who; and that the state of their empire mystically depended on the conversation of it.
# 65
# Some old prophecies were remembered upon this occasion, and the mummy committed prisoner to the Seven Towers, where it has remained under close confinement ever since, I dare not try my interest in so considerable a point, as the release of it; but I hope mine will pass without examination.
# 66
# I can  tell you nothing more at present of this famous city.
# 67
# When I have looked a little about me, you shall hear from me again.
# 68
# I am, Sir,   Your's, &c. &c.

# %% [markdown]
# Much better for my eyes!
#
# We will leave it at this for this notebook but in the next steps we will return to our sentences using the entire letter corpus!
