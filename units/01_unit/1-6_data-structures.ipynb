# %% [markdown]
# <center><b>Python Programming for Multilingual Texts</b></center>
# <center>1-6: Data Structures</center>
#
# ---

# %% [markdown]
# # Data Structures
#
# Now that you have learned about variable assignment and a few data types and how to convert them, know that you can store more than one piece of data inside a single variable.
#
# Some common structures to store data include lists, arrays, series, tuples, data frames, and dictionaries. Let's just focus on lists and dictionaries for now.
#
# <img src="../../img/python_elements.png" alt="Data Types and Structures in Python" width="700"/>

# %% [markdown]
# # List
#
# A list is a [mutable,](https://medium.com/@meghamohan/mutable-and-immutable-side-of-python-c2145cf72747) ordered, indexable collection of data. Each value is contained within square brackets and separated by a comma. Imagine you are researching literature, you can store your book names in a **list of strings**.
#
# `len()` will tell you how many books are in your library, while you can use an item's index `[]` to fetch if from a list:

# %%
library = ["Catch-22", "The Brothers Karamazov", "Little Women", "Crime and Punishment", 
           "The Alchemist", "Rashomon", "Catch-22", "Pride and Prejudice"]
library

# %%
# What is the the type of the library variable?
type(library)

# %%
# How many books are in library?
len(library)

# %% [markdown]
# *Note that `len()` is not zero-indexed.*

# %% [markdown]
# # Index and slice a list
#
# We can also index and slice lists just like we did strings in the last notebook.

# %%
print('The first book in library is:', library[0])
print('The fourth book in library is:', library[3])

# %%
# The first two books are:
library[:2]

# %%
# The last three books are:
library[-3:]

# %%
# The fourth and fifth books are:
library[3:5]

# %% [markdown]
# # Overwriting list elements
#
# We can overwrite individual elements in a list using variable assignment. Note that lists can contain values of different types!

# %%
# Where did The Brothers Karamazov go?
library[1] = "Things Fall Apart"
library

# %%
# What is going on in this assignment??
library[2], library[3] = 5, True
library

# %% [markdown]
# ### Lists have methods
#
# Just like strings (or mostly anything else in Python), data structures have methods as well - specific functions that only apply to lists! Type the name of your list followed by a period - a list of methods you can call should appear:

# %%
library.

# %%
# How many times does Catch-22 appear in library?
library.count("Catch-22")

# %% [markdown]
# The most common method for lists is the `append()` method, which adds an item to the end of a list.

# %%
library.append("Oliver Twist")
library

# %% [markdown]
# ### Of strings and lists: `.split()` method
#
# What does the .split() method do?
#
# What data type does it work on?
#
# What data structure is produced?

# %%
book = "Go Tell It on the Mountain"
book.split()

# %%
# You can use ? to get help about the method
book.split?

# %% [markdown]
# ### Adding Arguments
#
# As you can see, functions typically take their input between the parentheses (e.g. `type()` takes the variable you want to know the type of -> `type(book)`). Methods, on the other hand, don't always take values in between their parentheses (i.e. `book.lower()`).
#
# Methods (and functions too) can often take additional values that alter their behavior. These values, that go in between the parentheses, are called **arguments**. Let's try them out.

# %%
title = "Lettres de Milady Wortlay Montagute; écrites pendant ses voyages en diverses parties du monde; traduites de l'anglois"

# %%
title.split()

# %%
title.split(";")

# %%
title.split("e")

# %% [markdown]
# # Deleting list elements and variables
#
# **Deleting** elements of a list or an entire list can be done using `del`

# %%
# Delete just one item in a list - the element 7 is gone:
print(library)
del library[2]
print(library)

# %%
# Delete the entire list
del library

# What happens when you try to print the library variable after deleting it? 
print(library)

# %% [markdown]
# > You will learn more about error messages in notebook `1-3_errors-help.ipynb`

# %% [markdown]
# ### Note that lists can contain different data types, such as integers, floats, strings, and even other lists!

# %%
# A single list can hold strings, integers, floats, and booleans all at once
book_info = ["Catch-22", 1961]
# title (str), year published (int)
book_info

# %%
type(book_info[0])

# %%
type(book_info[1])

# %% [markdown]
# Let's add another item: did I read this book?

# %%
book_info.append(True)
book_info

# %%
type(book_info[2])

# %%
# When did I read this book?

book_info.append(2015)
book_info

# %%
type(book_info[3])

# %% [markdown]
# `extend()` method
#
# We have two identical pantries, let's append the new items to one and extendthem to the other

# %%
pantry_1 = ['bread', 'pasta', 'beans', 'cereal']
pantry_2 = ['bread', 'pasta', 'beans', 'cereal']
new_items = ['granola bars', 'cookies']

# %%
pantry_1.append(new_items)
print('append does this:', pantry_1)

# %%
pantry_2.extend(new_items)
print('extend does this:', pantry_2)

# %% [markdown]
# ### Nested lists or Lists of lists

# %%
list_of_lists = [[6, 3, 5], 
                 ["mountain", "forest", "ocean"], 
                 [5.0, 4.25, 12.823], 
                 True, 
                 False
                ]

list_of_lists

# %%
# Print the third thing in the second list
list_of_lists[1][2]

# %%
# Print the second thing in the third list
list_of_lists[2][1]

# %% [markdown]
# ### Of strings and lists 2: `join` method
#
# Using the join method, concatenate all the values in this list into one
#
# Note: join is a string method — the string you call it on becomes the separator, and you pass the list as the argument

# %%
# Here is a list of strings, making up the word spam
letters = ['s', 'p', 'a', 'm']

# %%
", ".join(letters)

# %% [markdown]
# Not quite what we wanted?

# %%
" ".join(letters)

# %% [markdown]
# Closer!

# %%
"".join(letters)

# %% [markdown]
# Think of it like the reverse method of `split()`: split breaks a string into a list, join glues a list back into a string
#
# Let's see another example:

# %%
Wheres_Waldo = ["Anna", "Shad", "Rachel", "Maura", "Jason", "Matt", "Konrad", "Justine", "Sarah", "Laura", "Chelsea", "Nina", "Dierdre", "Julian", "Waldo", "Naniette", "Melissa", "Biz", "Elsa", "Demetria", "Liz", "Olivia", "Will", "Ogi", "Melanie", "Jessica"]

# %%
# where is he really?

# Use the `.index()` method to find out what the index number is for `Waldo`

Wheres_Waldo.index("Waldo")

# %%
# If you could not find Waldo in a list, you won't find him in this crowd!

"|".join(Wheres_Waldo)

# %% [markdown]
# # Dictionary
#
# A python dictionary is an [ordered (in new versions of python)](https://medium.com/junior-dev/python-dictionaries-are-ordered-now-but-how-and-why-5d5a40ee327f) collection of **key/value pairs - the key is the name of the data, the value is the data itself**. By calling the key, you can always find its corresponding value. Keys must be unique and immutable; strings and integers are commonly used as keys. The values can be anything, including lists, and even other dictionaries.
#
# Each key/value pair is denoted by a colon `:` with the **key on the left side** and the **value on the right**. Each key/value pair within the dictionary is separate by a comma.
#
# > NOTE: we have seen round parentheses `()` for functions, square brackets `[]` for indexing/slicing, but now note the use of curly braces `{}` to define a dictionary.

# %%
my_list = []

# %%
my_dictionary = {"name": "Forough Farrokhzad"}
my_dictionary

# %%
poets_dict = {"name": "Forough Farrokhzad", 
            "year of birth": 1935, 
            "year of death": 1967, 
            "place of birth": "Iran", 
            "language": "Persian"}
type(poets_dict)

# %%
# print(poets_dict)
poets_dict

# %%
# Print the keys with the .keys() method
poets_dict.keys()

# %%
# Print the values with the .values() method
poets_dict.values()

# %%
# Call a particular key to see its value. 
# What language did Forough speak?
poets_dict["language"]

# %% [markdown]
# # Overwriting dictionary elements
#
# Like lists, we can also overwrite values (whatever they might be) in place:

# %%
# Overwrite "Persian" with "Farsi"
poets_dict["language"] = "Farsi"
poets_dict

# %% [markdown]
# We can also add **new** key/value pairs:

# %%
poets_dict["gender"] = "Female"
poets_dict

# %%
# This is what an actual dictionary of poets might look like

poets_dict ={
    "Forough Farrokhzad":{
        'name': 'Forough Farrokhzad',
        'year of birth': 1935,
        'year of death': 1967,
        'place of birth': 'Tehran',
        'language': 'Farsi',
        'gender': 'Female'
    },
    "Emily Dickinson":{
        'name': 'Emily Dickinson',
        'year of birth': 1830,
        'year of death': 1886,
        'place of birth': 'Amherst',
        'language': 'English',
        'gender': 'Female'
    }
}
poets_dict

# %%
poets_dict["Emily Dickinson"]["language"]

# %% [markdown]
# We can add lists as new values as well:

# %%
poets_dict["works"] = ['Remembrance of a Day', 'Unison',
                       'The Shower of Your Hair', 'Portrait of Forough']
poets_dict

# %% [markdown]
# ## Tuples
#
# Tuples are similar to lists and arrays, but they are unchangeable ("immutable").
#
# For example, we cannot change the output of 10 (the dividend) divided by 3 (the divisor) - by definition the quotient is 3 and the remainder is 1 this cannot be changed.
#
# > Although they appear similar to lists, note that tuples use round parentheses `()` to store information instead of square brackets.

# %%
div = divmod(10,3)
print(div)
print(type(div))

# %%
# Tuples use parentheses instead of square brackets

author = ("Toni", "Morrison", 1931)
author

# %%
# indexing works the same way as lists

print(author[0])   # first name
print(author[-1])  # birth year

# %%
# slicing too

author[:2]   # just the name parts

# %% [markdown]
# The key difference is that tuples are immutable

# %%
# This works for a list:
my_list = ["Toni", "Morrison", 1931]
my_list[0] = "James" 

my_list

# %%
# This breaks for a tuple:
author[0] = "James"    # TypeError!

# %% [markdown]
# Immutability is a very useful feature! We need a lot of things to be immutable so that we don't mistakenly edit them, like coordinates or publication years of works.

# %% [markdown]
# ### Sets
#
# A set is an unordered, unindexed collection of unique values — the key word being unique. It automatically drops duplicates.
#
# Like dictionaries, sets have curly braces, but no key/value pairs

# %%
# Remember our library from the very first example?

list_library = ["Catch-22", "The Brothers Karamazov", "Little Women", "Crime and Punishment", 
           "The Alchemist", "Rashomon", "Catch-22", "Pride and Prejudice"]
list_library
# Out:
# ['Catch-22',
#  'The Brothers Karamazov',
#  'Little Women',
#  'Crime and Punishment',
#  'The Alchemist',
#  'Rashomon',
#  'Catch-22',
#  'Pride and Prejudice']

# %%
set_library = set(list_library)
set_library
# Out:
# {'Catch-22',
#  'Crime and Punishment',
#  'Little Women',
#  'Pride and Prejudice',
#  'Rashomon',
#  'The Alchemist',
#  'The Brothers Karamazov'}

# %% [markdown]
# Main use of a set is to de-duplicate lists.
#
# But you cannot index a set!

# %%
# easy with a list
list_library[0]
# Out:
# 'Catch-22'

# %%
# not so much with a set
set_library[0]

# %% [markdown]
# Remember the definition! Sets are unordered and unindexed!
#
# But they are super useful for checking membership (whether or not something is in a set)

# %%
"Little Women" in set_library
# Out:
# True

# %%
"Oliver Twist" in set_library
# Out:
# False

# %% [markdown]
# Oliver Twist was a later addition to our library, we can still bring him in.
#
# Sets support math-style operations:

# %%
new_books = {"Oliver Twist"}
type(new_books)
# Out:
# set

# %%
updated_library = set_library | new_books
updated_library
# Out:
# {'Catch-22',
#  'Crime and Punishment',
#  'Little Women',
#  'Oliver Twist',
#  'Pride and Prejudice',
#  'Rashomon',
#  'The Alchemist',
#  'The Brothers Karamazov'}

# %%
"Oliver Twist" in updated_library
# Out:
# True

# %% [markdown]
# These are the other math-like functions with sets
#
# ```python
# A = {"fiction", "poetry", "biography"}
# B = {"poetry", "drama", "biography"}
#
# A & B   # intersection — what's in both: {"poetry", "biography"}
# A | B   # union — everything: {"fiction", "poetry", "biography", "drama"}
# A - B   # difference — in A but not B: {"fiction"}
# ```
